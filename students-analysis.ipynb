# %% [markdown]
# #### Load and prepare data:

# %%
# Import pandas, plotly and bokeh.
import pandas as pd
import plotly.plotly as py
from bokeh.plotting import figure,ColumnDataSource
from bokeh.io import output_notebook, show
from bokeh.models import HoverTool, NumeralTickFormatter
from bokeh.layouts import gridplot
from bokeh.charts import Histogram, Bar, output_file, Scatter,BoxPlot, output_file, show


# Assign spreadsheet filename: file
file = 'imd_student_blind.xlsx'

# Load spreadsheet: xl
xl = pd.ExcelFile(file)

# Print sheet names
print(xl.sheet_names)

# Load the sheet into a DataFrame by index: data
data = xl.parse(0)
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,wheel_zoom, pan'
# Out:
# ['Sheet1']

# %%
# Print the head of the DataFrame data
data.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota
# 0          0           640      618.0
# 1          0           640      618.0
# 2          0           660      615.0
# 3          0           560      600.0
# 4          0           760      673.0

# %%
source = ColumnDataSource(data)
data['count'] = 0
data.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota  count
# 0          0           640      618.0      0
# 1          0           640      618.0      0
# 2          0           660      615.0      0
# 3          0           560      600.0      0
# 4          0           760      673.0      0

# %%
d = data[data["status.disciplina"] == "Reprovado"]
df1 = pd.DataFrame(d.groupby(['disciplina_ID','ano_disciplina'])['count'].count()).reset_index()
df1.head(10)
# Out:
#    disciplina_ID  ano_disciplina  count
# 0              0            2014     73
# 1              0            2015    105
# 2              0            2016    143
# 3              1            2014     35
# 4              1            2015     29
# 5              1            2016     42
# 6              1            2017      3
# 7              2            2014     47
# 8              2            2015     47
# 9              2            2016    229

# %%
dataYear2014_ID = df1[df1["ano_disciplina"] == 2014]["disciplina_ID"]
dataYear2014_count = df1[df1["ano_disciplina"] == 2014]["count"]


dataYear2015_ID = df1[df1["ano_disciplina"] == 2015]["disciplina_ID"]
dataYear2015_count = df1[df1["ano_disciplina"] == 2015]["count"]

dataYear2016_ID = df1[df1["ano_disciplina"] == 2016]["disciplina_ID"]
dataYear2016_count = df1[df1["ano_disciplina"] == 2016]["count"]

dataYear2016_count.head(100)
# Out:
# 2     143
# 5      42
# 9     229
# 12    178
# 15     58
# 19    253
# 22    179
# Name: count, dtype: int64

# %%
#source = ColumnDataSource(df1)

Reprovados_Disc2014 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2014', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])
Reprovados_Disc2015 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2015', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])
Reprovados_Disc2016 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2016', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])


Reprovados_Disc2014.circle(dataYear2014_ID,dataYear2014_count,size=10,color = 'green')
Reprovados_Disc2015.circle(dataYear2015_ID,dataYear2015_count,size=10,color = 'navy')
Reprovados_Disc2016.circle(dataYear2016_ID,dataYear2016_count,size=10,color = 'red')
# Out:
# GlyphRenderer(id='b20e12fe-af07-4406-8edc-1950f1067717', ...)

# %% [markdown]
# ## Análise 1 - Número de Reprovados x Disciplina em cada ano.
#
# Nesta seção utilizamos os dados do número de reprovados em cada uma das disciplinas disponíveis, pelos anos em que elas foram ofertadas.
#
# "Há um sistema pré-estabelecido ao qual o aluno precisa se adaptar, se inserir, como um ritual de passagem. Quem não for capaz de cumprir etapas estabelecidas pela coordenação da disciplina, provavelmente, será reprovado.”
#
# #### Fabiana Colombo Garzella,
# **A disciplina de Cálculo I: a análise das relações entre as práticas pedagógicas do professor e seus impactos nos alunos**
#
# O Número de reprovados em algumas disciplinas do Curso do Bacharelado em Tecnologia da Informação, tem crescido rapidamente e é algo que deve ser revisado. Pensando nisso resolvemos analisar o número de reprovados em cada uma das disciplinas disponíveis, pelos anos em que elas foram ofertadas.
#
# Como visto, algumas disciplinas, a cada ano, tem seu número de reprovações aumentando. Além de outros possíveis fatores, a forma como a disciplina está sendo ofertada, a relação do aluno com os professores ou a quantidade de alunos em uma única turma, deve ser revisada pela coordenação ou setor pedagógico.
# Nos gráficos, podemos destacar a disciplina 5, que a cada ano aumenta o número de reprovados, chegando a 2016 com mais de 250 reprovações naquele ano. A disciplina 2, apesar de ter mantido esse valor de 2014 para 2015 com cerca de 50, teve em torno de 230 reprovações em 2016. A disciplina 3 também teve um aumento considerável, já que em 2014 o valor era de aproximadamente 50 para em torno de 180 em 2016.

# %%
row1 = [Reprovados_Disc2014,Reprovados_Disc2015]

# Create a list containing plots p3 and p4: row2
row2 = [Reprovados_Disc2016]

layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()

# Display the plot
show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="99739f0b-ebba-4bca-b75d-a5d003a33fc9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="149dc7d5-5695-4386-89b1-edfd29171feb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("149dc7d5-5695-4386-89b1-edfd29171feb").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("149dc7d5-5695-4386-89b1-edfd29171feb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '149dc7d5-5695-4386-89b1-edfd29171feb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fcde5561-eecb-4b87-8893-96af0cd4f429":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"05122354-4473-4db7-8adc-de0b3dde7313","type":"BoxAnnotation"},{"attributes":{},"id":"d8c67d32-ad58-449d-91dc-b4a53aaf1884","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"6240e1da-5ead-4bc6-82c1-abca731f63b4","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6],"y":[105,29,47,100,16,165,91]}},"id":"f719d25d-d28a-4f3b-a3fd-ff0fa8853742","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"c31be827-880a-4d9a-94b1-e75bc0c90449","subtype":"Figure","type":"Plot"}]},"id":"25a56215-956f-49a9-85e3-46ea27d860c0","type":"Row"},{"attributes":{"callback":null,"overlay":{"id":"70933c9d-bbcb-4d95-ac4f-b4e390c6cdc5","type":"BoxAnnotation"},"plot":{"id":"f3ef1623-09a5-4de6-a652-6604a16bb47e","subtype":"Figure","type":"Plot"},"renderers":[{"id":"390b818b-cbb0-4f91-ab88-0e3991763c00","type":"GlyphRenderer"}]},"id":"9d1da851-14a0-46a5-bbb8-db7635f7c1c5","type":"BoxSelectTool"},{"attributes":{},"id":"dc83dd9e-b6ce-4fb8-8f46-d85006f5bac3","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"86f12bdc-fd4a-4116-9b15-d4705acb1e7c","type":"BoxAnnotation"},"plot":{"id":"f3ef1623-09a5-4de6-a652-6604a16bb47e","subtype":"Figure","type":"Plot"}},"id":"bc290c63-abe3-458b-9742-42bd6bf2cc86","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6],"y":[73,35,47,56,14,105,33]}},"id":"bfceebe6-483f-468f-a925-d6245724fb13","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Scatter N\u00ba de reprovados pelas disciplinas, Ano de 2016"},"id":"80e25309-837b-4d60-9eb2-52cf984bd946","type":"Title"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"c5c7d507-ffc3-431f-a8b0-aeae2e411e68","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ca3be6ef-2b16-40c2-ac35-aad050350895","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"e2ee5a7c-c4f6-47b9-b811-33c00a3af435","type":"Row"},{"id":"25a56215-956f-49a9-85e3-46ea27d860c0","type":"Row"}]},"id":"4a0955db-81e7-4a38-8f19-656349559b80","type":"Column"},{"attributes":{"children":[{"id":"e111b327-122a-4b85-8ef2-41ec1fd79987","subtype":"Figure","type":"Plot"},{"id":"f3ef1623-09a5-4de6-a652-6604a16bb47e","subtype":"Figure","type":"Plot"}]},"id":"e2ee5a7c-c4f6-47b9-b811-33c00a3af435","type":"Row"},{"attributes":{},"id":"3a546ec7-26d3-445f-a31a-a75923c5b697","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c31be827-880a-4d9a-94b1-e75bc0c90449","subtype":"Figure","type":"Plot"}},"id":"7c591f12-5432-474a-a01a-68d5a659137c","type":"ResetTool"},{"attributes":{"plot":null,"text":"Scatter N\u00ba de reprovados pelas disciplinas, Ano de 2014"},"id":"83de72d0-3e7c-479f-936d-e695fe98e7b3","type":"Title"},{"attributes":{"plot":{"id":"c31be827-880a-4d9a-94b1-e75bc0c90449","subtype":"Figure","type":"Plot"}},"id":"0c6ff74b-a826-4355-9c54-b0d6ebae89d6","type":"ResizeTool"},{"attributes":{"children":[{"id":"7111a586-0617-4786-a34c-1832fedf554b","type":"ToolbarBox"},{"id":"4a0955db-81e7-4a38-8f19-656349559b80","type":"Colum ...

# %% [markdown]
# ## Análise 2 - Número de Reprovados x Disciplina em todos os anos.
#
# Nesta seção utilizamos os dados do número de reprovados em cada uma das disciplinas disponíveis, em todos os anos.
#
# "Entre os fatores determinantes para esse quadro, a pesquisa relaciona o grande número de alunos por turma, impedindo que necessidades particulares de determinados grupos de alunos sejam atendidas. No caso do semestre observado, existiam 30 turmas da disciplina, com média de 40 alunos cada. Três turmas eram agrupadas em uma sala de aula, totalizando aproximadamente 150 alunos. No conjunto, havia 10 salas composta por três turmas, cada uma com um professor responsável."
#
# #### Fabiana Colombo Garzella,
# **A disciplina de Cálculo I: a análise das relações entre as práticas pedagógicas do professor e seus impactos nos alunos**
#
# Como podemos ver abaixo, o crescente número de reprovados também pode ser influenciado pela necessidade de compensar alunos reprovados em semestres anteriores, aumentando a quantidade de de alunos por turma e consequentemente, a necessidade de abrir mais turmas para as diciplinas.
# No gráfico, podemos ver a disciplina 5 com um total de mais de 500 reprovados somandos todas as suas ofertas desde o ano de 2014 até o ano de 2016. Enquanto outras disciplinas, não menos importantes tem um valor considerevável com algo em torno de 320 reprovações. As disciplinas 1 e 4 possuem o menor número, com cerca de 120 e 160 respectivamente.

# %%
#from bokeh.plotting import figure, output_file, show

#mypalette = Spectral11[0:10]
#source = ColumnDataSource(df1)

#df1.plot(kind = 'line')
Bar_Reprovados = Bar(df1, 'disciplina_ID', values='count',color = 'disciplina_ID', xlabel="Disciplina",  
         ylabel = "Nº de Reprovados", title="Disciplinas pelo Nº de Reprovados", 
         legend = 'top_right', width = 10,tools=[TOOLS])

output_notebook()
show(Bar_Reprovados)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e5fa4fe1-1f81-447e-a0c5-e8ac942b71ee">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de2983ba-e74b-4c04-88fe-d7945bc00dd0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("de2983ba-e74b-4c04-88fe-d7945bc00dd0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("de2983ba-e74b-4c04-88fe-d7945bc00dd0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'de2983ba-e74b-4c04-88fe-d7945bc00dd0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d2ddadd5-7dcc-439c-bc37-8b2ed3e9a25a":{"roots":{"references":[{"attributes":{"callback":null,"end":549.15},"id":"0248c7f0-980e-4d65-8c9c-303edcebbe35","type":"Range1d"},{"attributes":{"plot":null,"text":"Disciplinas pelo N\u00ba de Reprovados"},"id":"c0a7a429-d22d-4e19-a953-04517de34a1f","type":"Title"},{"attributes":{"label":{"value":"6"},"renderers":[{"id":"ce970ac7-fb94-4b6e-bd3b-df18e471467c","type":"GlyphRenderer"}]},"id":"feda64a6-47a1-4c41-b2c0-1943f28b12ec","type":"LegendItem"},{"attributes":{},"id":"5aed618b-0f36-49bd-a2e5-7f5e0715c48f","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"41a65524-c7eb-4606-8add-6928dfe8a560","subtype":"Chart","type":"Plot"},"ticker":{"id":"d32d0137-8a2c-4c62-a03f-7d4589f0d099","type":"BasicTicker"}},"id":"429deb7b-f4f0-446d-9e3f-b0941e5b707c","type":"Grid"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"606d9828-15c9-44fd-a6be-9c86c695c714","type":"GlyphRenderer"}]},"id":"db3253a4-f707-46bf-8912-e82989cb7e7a","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6acfb5f9-b582-43e3-a6b0-4b3004f572d7","type":"BoxZoomTool"},{"id":"00226883-8ac4-48a4-91d3-2d291510b4fb","type":"BoxSelectTool"},{"id":"4061ce78-a13b-48ee-8065-ae0f8b208625","type":"CrosshairTool"},{"id":"a8117c92-2897-4ba2-9f4d-755602bdc202","type":"ResizeTool"},{"id":"b8ba7194-9a52-48af-9490-a0716ceced47","type":"ResetTool"},{"id":"7f6e755e-674a-4332-b4e7-446bbc45b747","type":"WheelZoomTool"},{"id":"658584c6-76c6-4744-9b8e-ad066b936c47","type":"PanTool"}]},"id":"d1686867-44b8-43aa-a840-ded89697395e","type":"Toolbar"},{"attributes":{"axis_label":"N\u00ba de Reprovados","formatter":{"id":"4d8c33ba-648d-4be5-95cb-a14d780c4efd","type":"BasicTickFormatter"},"plot":{"id":"41a65524-c7eb-4606-8add-6928dfe8a560","subtype":"Chart","type":"Plot"},"ticker":{"id":"d32d0137-8a2c-4c62-a03f-7d4589f0d099","type":"BasicTicker"}},"id":"484198d8-a988-4075-9fb1-e7609efebc6b","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"99daa8db-ad7e-4e35-8198-89a4ba79844a","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"99daa8db-ad7e-4e35-8198-89a4ba79844a","type":"BoxAnnotation"},"plot":{"id":"41a65524-c7eb-4606-8add-6928dfe8a560","subtype":"Chart","type":"Plot"}},"id":"6acfb5f9-b582-43e3-a6b0-4b3004f572d7","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8193bcc1-cca5-4e25-a77f-e46a07b2387e","type":"Rect"},{"attributes":{"callback":null,"factors":["0","1","2","3","4","5","6"]},"id":"cfe45995-00d5-4854-a722-927170308eb8","type":"FactorRange"},{"attributes":{"callback":null,"overlay":{"id":"149aa604-a131-4675-8d5b-17fac081acf0","type":"BoxAnnotation"},"plot":{"id":"41a65524-c7eb-4606-8add-6928dfe8a560","subtype":"Chart","type":"Plot"}},"id":"00226883-8ac4-48a4-91d3-2d291510b4fb","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"41a65524-c7eb-4606-8add-6928dfe8a560","subtype":"Chart","type":"Plot"}},"id":"4061ce78-a13b-48ee-8065-ae0f8b208625","type":"CrosshairTool"},{"attributes":{"label":{"value":"2"},"renderers":[{"id":"9bd5f26c-d5ab-4c4b-8f59-a2bbb784d691","type":"GlyphRenderer"}]},"id":"4a83f010-cef1-4b8e-b68b-8b1fd81dc8b9","type":"LegendItem"},{"attributes":{"plot":{"id":"41a65524-c7eb-4606-8add-6928dfe8a560","subtype":"Chart","type":"Plot"}},"id":"a8117c92-2897-4ba2-9f4d-755602bdc202","type":"ResizeTool"},{"attributes":{"plot":{"id":"41a65524-c7eb-4606-8add-6928dfe8a560","subtype":"Chart","type":"Plot"}},"id":"b8ba7194-9a52-4 ...

# %%
data2 = data
data2['count'] = 0
data2.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota  count
# 0          0           640      618.0      0
# 1          0           640      618.0      0
# 2          0           660      615.0      0
# 3          0           560      600.0      0
# 4          0           760      673.0      0

# %%
dataYear2014_nota = data2[data2["ano_disciplina"] == 2014]
dataYear2015_nota = data2[data2["ano_disciplina"] == 2015]
dataYear2016_nota = data2[data2["ano_disciplina"] == 2016]

# %%
NotasYear2014 = BoxPlot(dataYear2014_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID', legend = False, 
             title = "BoxPlot das disciplinas pelas notas, Ano 2014", tools = [TOOLS])

NotasYear2015 = BoxPlot(dataYear2015_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2015", tools = [TOOLS])

NotasYear2016 = BoxPlot(dataYear2016_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2016", tools = [TOOLS])

# %% [markdown]
# ## Análise 3 - Disciplinas x Notas em cada ano.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# "Pesquisas recentes têm observado que muitos fatores podem influenciar o desempenho de um estudante: conhecimentos anteriores, infraestrutura (materiais adequados e espaço físico para estudar), emocionais (estresse e autoconfiança), desempenho do professor (didática, pontualidade, provas em nível adequado e indicação de literatura apropriada) e esforço pessoal do estudante (estar presente nas aulas, prestar atenção, tirar dúvidas, estudar em casa e saber administrar o tempo)."
#
# #### Cesar Duarte Souto-Maior, José Alonso Borba, Paulo de Souza Knupp, Eva de Souza Croll
# **Análise de Fatores que Afetam o Desempenho de Alunos de Graduação em Administração e Contabilidade na Disciplina de Pesquisa Operacional**
#
# Analisando as disciplinas, no ano de 2014, podemos ver as disciplinas 3 e 5, com medianas em 2,2 e 2,9 respectavemente, que consideram o valor da média final da maioria dos alunos. Mas enquanto a disciplina 3 se mantém com o mesmo valor no decorrer dos anos, a disciplina 5 em 2016 teve como mediana 1,8 e cerca de 50% dos alunos com nota final igual ou inferior a 4,1.
# As disciplinas 1, 2 e 4 matém os mesmos níveis de distribuições no decorrer dos anos. A disciplina 6 teve uma distribuição menos concentrada nos anos de 2015 e 2016.

# %%
row1 = [NotasYear2014,NotasYear2015]

# Create a list containing plots p3 and p4: row2
row2 = [NotasYear2016]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="feec4852-b504-4bdb-b6ea-6dfb15d54026">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d2991f4a-d6d9-4845-a6b0-e574f5ec5564"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d2991f4a-d6d9-4845-a6b0-e574f5ec5564").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d2991f4a-d6d9-4845-a6b0-e574f5ec5564");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd2991f4a-d6d9-4845-a6b0-e574f5ec5564' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"784c9b69-83d2-427f-bd7c-6a4c55290858":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4c79f70a-ef58-4356-8035-5b1531784d6a","type":"Rect"},{"attributes":{"data_source":{"id":"e94323bc-0275-404c-8155-558d9f088f3f","type":"ColumnDataSource"},"glyph":{"id":"a400b68c-0a4b-4859-be57-662b416aa0df","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"69a8a210-95e9-44f2-a03d-4046100ed75e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"17683b42-8ab4-458d-94a6-0365fd7b880f","type":"ColumnDataSource"},"glyph":{"id":"b9cea916-cca1-4be1-ab8f-73a633584db6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c470917e-5bfa-4d7a-9744-a2251e5674bb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1e1493f7-550e-4806-bae1-732f693fd5a0","type":"ColumnDataSource"},"glyph":{"id":"e93b3efe-546c-417e-bb78-65717f51988f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"11eea06c-0f3e-4661-9b1d-95a929355add","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"7b3f82fc-7cd6-4e19-97ee-f6fcff16b6eb","type":"Segment"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":5}],"color":["#c33ff3"],"disciplina_ID":[5],"fill_alpha":[0.8],"height":[1.05],"label":[{"disciplina_ID":5}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["5"],"y":[0.9750000000000001]}},"id":"17683b42-8ab4-458d-94a6-0365fd7b880f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":0}],"color":["#f22c40"],"disciplina_ID":[0],"fill_alpha":[0.8],"height":[2.05],"label":[{"disciplina_ID":0}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["0"],"y":[6.675000000000001]}},"id":"3a4047ec-eaba-4d89-a52d-8cd760ba7d47","type":"ColumnDataSource"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"c347171a-84b9-4144-bc76-ca733882c5aa","type":"BoxZoomTool"},{"id":"6eba20ae-f7ee-4379-a08b-c2f1aebcc311","type":"BoxSelectTool"},{"id":"ed229a89-4ada-48f6-8520-36e278d9e66d","type":"CrosshairTool"},{"id":"46ccabf0-695a-48e5-b3e3-3406f36bfa94","type":"ResizeTool"},{"id":"ba3388c6-e7e4-4b54-b07e-d57d577d4f5a","type":"ResetTool"},{"id":"96f43596-56c6-4309-bdc7-34a8ac7bbf52","type":"WheelZoomTool"},{"id":"27b2ddd9-37ba-4140-8828-3cea83155fea","type":"PanTool"},{"id":"ba3c7536-1a1b-4af1-82ef-3eeee5f1ee03","type":"BoxZoomTool"},{"id":"412af1a8-7b42-4232-8708-5cb57108cf48","type":"BoxSelectTool"},{"id":"df581e8b-8d84-49a9-a165-ffd2d4d8344a","type":"CrosshairTool"},{"id":"e73347fd-a0db-4cf6-92f0-9941599ac6d7","type":"ResizeTool"},{"id":"bc9f6dc2-3028-4ae2-9239-9a338fd27b17","type":"ResetTool"},{"id":"8d002f09-0715-4f24-91d3-3fec9720b598","type":"WheelZoomTool"},{"id":"1e89e632-f480-4617-85af-80f323986f7f","type":"PanTool"},{"id":"adb863c3-2dce-4c4a-809b-9fec65d4c63b","type":"BoxZoomTool"},{"id":"fe4d1d83-49bc-4505-9396-081206fb9a0b","type":"BoxSelectTool"},{"id":"1a61643b-ac27-43d8-af3f-40b9eed48e78","type":"CrosshairTool"},{"id":"fb38efc3-658e-4006-bfa6-907e8331f1ce","type":"ResizeTool"},{"id":"5c4d882c-7d22-40b8-a1cd-3a770d69c649","type":"ResetTool"},{"id":"27a86002-9caf-4971-b1d1-a42dc2c8b0ca","type":"WheelZoomTool"},{"id":"a5847a9e-790a-4a08-8c46-b08d4b12b497","type":"PanTool"}]},"id":"61c25fbc-2fd9-4c88-9329-1ac60bc4c5a3","type":"ToolbarBox"},{"attributes":{"callback":null,"column_names":["x","y","width","height" ...

# %% [markdown]
# ## Análise 4 - Disciplinas x Notas em todos os anos.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# Analisando as disciplinas, podemos ver as disciplinas 3 e 5, com quase 50% de seus alunos com médias abaixo de 5.
# As disciplinas 1 e 4 matém os mesmos níveis de distribuições, olhando para o fato de terem vários Outliers. A disciplina 6 teve uma distribuição menos concentrada com mediana aproximadamente em 4 e as disciplinas 0 e 2 com valores próximos a 5,2.

# %%
BoxPlot_Nota = BoxPlot(data, values='nota', label='disciplina_ID', legend = 'top_right', color = 'disciplina_ID', tools = [TOOLS])

output_notebook()


show(BoxPlot_Nota)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="19f67262-3991-4ed8-9736-cfb347327cd8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fdbbd9a5-9eff-4409-94d8-b298ab2a4c60"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fdbbd9a5-9eff-4409-94d8-b298ab2a4c60").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fdbbd9a5-9eff-4409-94d8-b298ab2a4c60");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fdbbd9a5-9eff-4409-94d8-b298ab2a4c60' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"be48e176-a608-4383-ad1e-b83aeaff5c07":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d66c8a0-dfaf-4015-a96a-92f4bd1aed86","type":"Rect"},{"attributes":{"items":[{"id":"13bd5366-f23c-430b-837c-ea756d3ff8e7","type":"LegendItem"},{"id":"f4a01662-8965-44b1-8c38-274149865979","type":"LegendItem"},{"id":"f25c4808-bd96-4581-8d2a-a99c053a3d39","type":"LegendItem"},{"id":"7796bace-2fc0-4327-9593-e63f894ff1fc","type":"LegendItem"},{"id":"a38a3800-94a4-4a70-b07f-5af6d522c2f2","type":"LegendItem"},{"id":"2701e7c0-14c6-49fc-8825-1cd1baa45c58","type":"LegendItem"},{"id":"27b2106f-439a-4bdd-8f11-62f499f54e02","type":"LegendItem"}],"plot":{"id":"6d6d8a25-8eaf-4858-8ecb-897e43a9f7e4","subtype":"Chart","type":"Plot"}},"id":"3ca85c17-4b86-441d-a957-87ad2c370d19","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"612f18c5-ec77-4f6b-9e18-f8d8e8e152ba","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":4}],"color":["#00ad9c"],"disciplina_ID":[4],"fill_alpha":[0.8],"height":[0.8499999999999996],"label":[{"disciplina_ID":4}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["4"],"y":[6.375]}},"id":"aa3eb4e3-88b7-4100-8a20-d309da74b51e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":6}],"color":["#f22c40"],"disciplina_ID":[6],"fill_alpha":[0.8],"height":[3.3],"label":[{"disciplina_ID":6}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["6"],"y":[2.65]}},"id":"6757a9c1-31d3-4c2e-bd4c-afd56715be72","type":"ColumnDataSource"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"1d5e0d56-8e15-48bb-8e74-e8997467a0c8","type":"Segment"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":5}],"color":["#c33ff3"],"disciplina_ID":[5],"fill_alpha":[0.8],"height":[3.3],"label":[{"disciplina_ID":5}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["5"],"y":[3.85]}},"id":"39e48815-b395-45fe-9808-add9a2ab23f3","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"disciplina_ID":5},{"disciplina_ID":5},{"disciplina_ID":5},{"disciplina_ID":5}],"disciplina_ID":[5,5,5,5],"x0s":["5:0.5","5:0.65","5:0.5","5:0.65"],"x1s":["5:0.5","5:0.35","5:0.5","5:0.35"],"y0s":[0.0,0.0,5.5,10.0],"y1s":[0.8,0.0,10.0,10.0]}},"id":"0be56763-d7b6-44ee-a1a4-d01785a580c0","type":"ColumnDataSource"},{"attributes":{},"id":"bee3316f-af5a-4e12-a3bb-32b3a6443f79","type":"ToolEvents"},{"attributes":{"data_source":{"id":"aa3eb4e3-88b7-4100-8a20-d309da74b51e","type":"ColumnDataSource"},"glyph":{"id":"8d66c8a0-dfaf-4015-a96a-92f4bd1aed86","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b885751c-302e-451d-b26c-2e3a462822bb","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":10.5},"id":"e01a1dd3-fd5b-42d5-a24d-74e1211b6d4f","type":"Range1d"},{"attributes":{"data_source":{"id":"0be56763-d7b6-44ee-a1a4-d01785a580c0","type":"ColumnDataSource"},"glyph":{"id":"1d5e0d56-8e15-48bb-8e74-e8997467a0c8","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c65c33bf-f62d-48b6-87ac-251c32149180","type":"G ...

# %%
Notas_Enem2014 = BoxPlot(data, values='enen-nota', label='ano_ingresso', color = 'ano_ingresso', legend = 'bottom_right', 
             title = "BoxPlot Notas do Enem pelo Ano de Ingresso", tools = [TOOLS])

Notas_Enem2015 = BoxPlot(data, values='enem-redacao', label='ano_ingresso', color = 'ano_ingresso', legend = 'bottom_right', 
             title = "BoxPlot Notas da Redação Enem pelo Ano de Ingresso", tools = [TOOLS])
Notas_Enem2016 = BoxPlot(data, values='enem-matematica', label='ano_ingresso', color = 'ano_ingresso', legend = False, 
             title = "BoxPlot Notas de Matemática Enem pelo Ano de Ingresso", tools = [TOOLS])

# %% [markdown]
# ## Análise 5 - Notas Enem x Ano de Ingresso.
#
# Nesta seção utilizamos os dados das notas do Enem dos alunos em relação ao ano de ingresso.
#
# No primeiro Gráfico, podemos ver que apesar de alguns poucos Outliers para cima ou para baixo da distruibuição, a média geral dos alunos se manteve próxima aos 620 pontos em todos oos anos.
#
# No segundo Gráfico para as notas da redação, com uma distruibuição um pouco menos concentrada do que as notas gerais, ainda assim temos cerca 50% dos alunos com notas em torno de 600 à bem próximo dos 800, que no geral chegam a ser boas notas.
#
# No terceiro Gráfico............

# %%
row1 = [Notas_Enem2014,Notas_Enem2015]

# Create a list containing plots p3 and p4: row2
row2 = [Notas_Enem2016]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3ae5ec11-3e88-46e1-b433-b50270fc4f41">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6768f736-372b-41c0-8f4d-6410a4a03e6f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6768f736-372b-41c0-8f4d-6410a4a03e6f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6768f736-372b-41c0-8f4d-6410a4a03e6f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6768f736-372b-41c0-8f4d-6410a4a03e6f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"06d90b78-03db-4936-a406-e308e56fbb58":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b524674a-7160-4a5e-8192-ace8aec1af85","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"557a71cc-79f4-4eb5-8992-c62f21368996","type":"ColumnDataSource"},"glyph":{"id":"d8c6d3df-77ff-4f98-84d5-318d093b4bbb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a2a5c780-6601-4326-95c9-2601e0941ddf","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"b524674a-7160-4a5e-8192-ace8aec1af85","type":"BoxAnnotation"},"plot":{"id":"12caa2d1-ef1e-4e61-be58-bf13b0c513a7","subtype":"Chart","type":"Plot"}},"id":"7bc8af1e-0835-4d72-aadf-90b094f09abd","type":"BoxZoomTool"},{"attributes":{"callback":null,"overlay":{"id":"6e6f5060-3862-4c50-87b0-a0b28d107fac","type":"BoxAnnotation"},"plot":{"id":"12caa2d1-ef1e-4e61-be58-bf13b0c513a7","subtype":"Chart","type":"Plot"}},"id":"f6abb33c-7929-406a-ae99-456503d1fdbf","type":"BoxSelectTool"},{"attributes":{},"id":"04347220-7a30-46ad-a3ca-e5938a956eee","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"efae0eef-0b2c-425e-9901-636fe42090c5","type":"Rect"},{"attributes":{"plot":{"id":"12caa2d1-ef1e-4e61-be58-bf13b0c513a7","subtype":"Chart","type":"Plot"}},"id":"4ad66c03-1946-45ce-b534-bc1c70cd65d4","type":"CrosshairTool"},{"attributes":{"plot":{"id":"12caa2d1-ef1e-4e61-be58-bf13b0c513a7","subtype":"Chart","type":"Plot"}},"id":"84dcb933-dbbe-4c04-9773-7ef9c5f6c2bd","type":"ResizeTool"},{"attributes":{"plot":{"id":"12caa2d1-ef1e-4e61-be58-bf13b0c513a7","subtype":"Chart","type":"Plot"}},"id":"5661f075-4e97-4494-83de-6ccef244b094","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"f2a8b3f3-8d23-473f-9b14-57e8af4fde81","type":"Circle"},{"attributes":{"plot":{"id":"12caa2d1-ef1e-4e61-be58-bf13b0c513a7","subtype":"Chart","type":"Plot"}},"id":"2337a4fb-0a1f-4159-9ac4-3aba770a31d0","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"12caa2d1-ef1e-4e61-be58-bf13b0c513a7","subtype":"Chart","type":"Plot"}},"id":"049539cf-0ad1-4fd7-880a-35e913146508","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6e6f5060-3862-4c50-87b0-a0b28d107fac","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"ab017b62-c00a-4bb7-96ce-fcc45017c3ba","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"7ed87efa-0ecc-4620-95bc-cc0e5be79f9b","type":"LinearAxis"}],"plot_height":450,"plot_width":450,"renderers":[{"id":"855eaad4-8125-4204-a5a3-10ca3acdc840","type":"BoxAnnotation"},{"id":"bac96481-e3be-4ffc-8fb3-ed85ee51b625","type":"BoxAnnotation"},{"id":"f82f0aec-9996-4bb3-80a5-c7569383d6df","type":"GlyphRenderer"},{"id":"bb623479-0a6c-43d0-8ecf-c824aa7049b6","type":"GlyphRenderer"},{"id":"750998dd-fcb7-4ae3-b2f9-fd9a325a6fac","type":"GlyphRenderer"},{"id":"a2296550-5bf2-4abd-90d9-6df134d757d8","type":"GlyphRenderer"},{"id":"e9597b75-c26f-46f5-84af-85362778e881","type":"GlyphRenderer"},{"id":"7fdef2d8-9eef-4af0-b90a-2f83f7f432da","type":"GlyphRenderer"},{"id":"64708acf-b947-450d-a85a-2cecbb2e5de8","type":"G ...

# %% [markdown]
# ### Usando plotly para gerar gráficos pizza de acordo com os dados fornecidos.

# %%
# Filter by status (ATIVO, CANCELADO and TRANCADO)
a = data
a = a.loc[a['status'] != 'FORMADO']
a = a.loc[a['status'] != 'FORMANDO']
a = a.loc[a['status'] != 'CONCLUIDO']
a = a.loc[a['status'] != 'FORMADO']
a = pd.DataFrame(a.groupby('status')['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2014
a14 = data.loc[data['ano_ingresso'] == 2014]
a14 = a14.loc[a14['status'] != 'FORMADO']
a14 = a14.loc[a14['status'] != 'FORMANDO']
a14 = a14.loc[a14['status'] != 'CONCLUIDO']
a14 = a14.loc[a14['status'] != 'FORMADO']
a14 = pd.DataFrame(a14.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2015
a15 = data.loc[data['ano_ingresso'] == 2015]
a15 = a15.loc[a15['status'] != 'FORMADO']
a15 = a15.loc[a15['status'] != 'FORMANDO']
a15 = a15.loc[a15['status'] != 'CONCLUIDO']
a15 = a15.loc[a15['status'] != 'FORMADO']
a15 = pd.DataFrame(a15.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2016
a16 = data.loc[data['ano_ingresso'] == 2016]
a16 = a16.loc[a16['status'] != 'FORMADO']
a16 = a16.loc[a16['status'] != 'FORMANDO']
a16 = a16.loc[a16['status'] != 'CONCLUIDO']
a16 = a16.loc[a16['status'] != 'FORMADO']
a16 = pd.DataFrame(a16.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# %%
# Load data from dataframes into figure object
fig = {
    'data': [
        {
            'labels': a16['status'],
            'values': a16['a_ID'],
            'type': 'pie',
            'name': '2016',
            'domain': {'x': [0, .48], 'y': [0, .49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a['status'],
            'values': a['a_ID'],
            'type': 'pie',
            'name': '2014-2016',
            'domain': {'x': [.52, 1], 'y': [0, .49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a14['status'],
            'values': a14['a_ID'],
            'type': 'pie',
            'name': '2014',
            'domain': {'x': [0, .48], 'y': [.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a15['status'],
            'values': a15['a_ID'],
            'type': 'pie',
            'name':'2015',
            'domain': {'x': [.52, 1], 'y': [.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Distribuição de alunos por ano de ingresso e situação',
        'annotations':[
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2014',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2015',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2016',
                    'x': 0.21,
                    'y': 0.21
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': '14 - 16',
                    'x': 0.79,
                    'y': 0.21
                }
        ]
    }
}

# %% [markdown]
# ## Análise 6 - Ano de Ingresso x Status.
#
# Para verificar o andamento anual do curso, decidimos analisar a situação dos alunos (status) a cada ano e também ao total dos 3 anos.
#
# Nesta seção utilizamos os dados dos status dos alunos em relação ao seus anos de ingresso.

# %%
# Plot pie charts
py.iplot(fig)
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~rubemkalebe/0 or inside your plot.ly account where it is named 'plot from API'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~rubemkalebe/0.embed" height="525px" width="100%"></iframe>

# %%
d = data
d['count'] = 0

# Filter by qtd_matriculas and disciplina 0
d0 = d[d['disciplina_ID']==0]
d0 = pd.DataFrame(d0.groupby('a_ID')['count'].count()).reset_index()
d0 = d0.rename(columns = {'count':'qtd_matriculas'})
d0['count'] = 0
d0 = pd.DataFrame(d0.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 1
d1 = d[d['disciplina_ID']==1]
d1 = pd.DataFrame(d1.groupby('a_ID')['count'].count()).reset_index()
d1 = d1.rename(columns = {'count':'qtd_matriculas'})
d1['count'] = 0
d1 = pd.DataFrame(d1.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 2
d2 = d[d['disciplina_ID']==2]
d2 = pd.DataFrame(d2.groupby('a_ID')['count'].count()).reset_index()
d2 = d2.rename(columns = {'count':'qtd_matriculas'})
d2['count'] = 0
d2 = pd.DataFrame(d2.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 3
d3 = d[d['disciplina_ID']==3]
d3 = pd.DataFrame(d3.groupby('a_ID')['count'].count()).reset_index()
d3 = d3.rename(columns = {'count':'qtd_matriculas'})
d3['count'] = 0
d3 = pd.DataFrame(d3.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 4
d4 = d[d['disciplina_ID']==4]
d4 = pd.DataFrame(d4.groupby('a_ID')['count'].count()).reset_index()
d4 = d4.rename(columns = {'count':'qtd_matriculas'})
d4['count'] = 0
d4 = pd.DataFrame(d4.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 5
d5 = d[d['disciplina_ID']==5]
d5 = pd.DataFrame(d5.groupby('a_ID')['count'].count()).reset_index()
d5 = d5.rename(columns = {'count':'qtd_matriculas'})
d5['count'] = 0
d5 = pd.DataFrame(d5.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 6
d6 = d[d['disciplina_ID']==6]
d6 = pd.DataFrame(d6.groupby('a_ID')['count'].count()).reset_index()
d6 = d6.rename(columns = {'count':'qtd_matriculas'})
d6['count'] = 0
d6 = pd.DataFrame(d6.groupby('qtd_matriculas')['count'].count()).reset_index()

# %%
# Load data from dataframes into figure object
fig1 = {
    'data': [
        {
            'labels': d2['qtd_matriculas'],
            'values': d2['count'],
            'type': 'pie',
            'name': 'Disciplina 2',
            'domain': {'x': [0, .48], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d3['qtd_matriculas'],
            'values': d3['count'],
            'type': 'pie',
            'name': 'Disciplina 3',
            'domain': {'x': [.52, 1], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d0['qtd_matriculas'],
            'values': d0['count'],
            'type': 'pie',
            'name': 'Disciplina 0',
            'domain': {'x': [0, .48], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d1['qtd_matriculas'],
            'values': d1['count'],
            'type': 'pie',
            'name':'Disciplina 1',
            'domain': {'x': [.52, 1], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Disciplina pela Quantidade de vezes que alunos se matricularam (Disciplina 0 à 3)',
        'annotations':[
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_0',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_1',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_2',
                    'x': 0.21,
                    'y': 0.21
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_3',
                    'x': 0.79,
                    'y': 0.21
                }
        ]
    }
}

# %% [markdown]
# ## Análise 7 - Disciplina x Quantida de vezes que alunos se matricularam
#
# De acordo com o regulamento da UFRN, é previsto o cancelamento do programa se houver desempenho acadêmico insuficiente por parte do aluno. Ainda de acordo com o regulamento, **Seção III (15.16.3. DO DESEMPENHO ACADÊMICO INSUFICIENTE), Art. 327 - I**:
#
# ***"Caracteriza-se o desempenho acadêmico insuficiente quando, em um período letivo regular no qual o programa não está suspenso, ocorre uma ou mais das seguintes situações: Insucesso (trancamento e/ou reprovação) pela quarta vez ou mais, consecutiva ou não, em um mesmo componente curricular obrigatório ou seus equivalentes;"***
#
#
# Com o objetivo de verificar o andamento de cada disciplina e assim analisar quais têm causado mais dificuldades aos alunos, inclusive abrindo possibilidades de cancelamento de seus programas, levantamos os dados que mostram a quantidade de vezes que os alunos se matricularam nas disciplinas no decorrer do tempo (intervalo de 2014 à 2016).

# %%
# Plot pie charts
py.iplot(fig1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~rubemkalebe/2.embed" height="525px" width="100%"></iframe>

# %%
fig2 = {
    'data': [
        {
            'labels': d6['qtd_matriculas'],
            'values': d6['count'],
            'type': 'pie',
            'name': 'Disciplina 6',
            'domain': {'x': [0, .48], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d4['qtd_matriculas'],
            'values': d4['count'],
            'type': 'pie',
            'name': 'Disciplina 4',
            'domain': {'x': [0, .48], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d5['qtd_matriculas'],
            'values': d5['count'],
            'type': 'pie',
            'name':'Disciplina 5',
            'domain': {'x': [.52, 1], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Disciplina pela Quantidade de vezes que alunos se matricularam (Disciplina 4 à 6)',
        'annotations':[
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_4',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_5',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_6',
                    'x': 0.21,
                    'y': 0.21
                }
        ]
    }
}

# %%
py.iplot(fig2)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~rubemkalebe/4.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Análise 8 - Evolução temporal das disciplinas
#
# Nesta seção utilizamos a quantidade de aprovados e reprovados, além do total de matriculados em cada disciplina, para mostrar o desenvolvimento de cada disciplina no decorrer dos anos em que foram ofertadas.
#
# A análise do quanto uma disciplina vem aprovando, ou reprovando, é útil para encontrar disciplinas nas quais os estudantes apresentam dificuldades ou ainda, disciplinas que eventualmente têm se tornado mais complicada para eles. Um gráfico de linhas é ideal para apresentar essa evolução no decorrer do tempo.
#
# À primeira vista, percebe-se que os alunos apresentam mais dificuldades nas disciplinas 3, 5 e 6. A disciplina 0 também apresenta-se de complexidade razoável e a disciplina 2, a qual antes não poderia ser considerada de grande complexidade, passou a reprovar a maior parte dos seus alunos.
#
# As disciplinas 1 e 4 aparentam serem melhor aproveitadas pelos alunos e a tendência de crescimento na quantidade de matriculados mostra que essas disciplinas não sofreram mudanças que alterassem a tendência de aprovação.
#
# A disciplina 6 apresenta uma tendência preocupante de "reprovar mais do que aprovar". Com o passar dos anos, a quantidade de aprovados praticamente se manteve constante, enquanto que a quantidade de reprovados cresceu linearmente.

# %%
df1 = data[data['ano_disciplina'] != 2017]
df1['count_reprovados'] = 0
df1['count_aprovados'] = 0
df1['count_total'] = 0
df1['count_rep_periodo'] = 0

reprovados = df1[df1["status.disciplina"] == "Reprovado"]
aprovados = df1[df1["status.disciplina"] == "Aprovado"]

reprovados_count = pd.DataFrame(reprovados.groupby(['disciplina_ID','ano_disciplina'])['count_reprovados'].count()).reset_index()
aprovados_count = pd.DataFrame(aprovados.groupby(['disciplina_ID','ano_disciplina'])['count_aprovados'].count()).reset_index()
total_count = pd.DataFrame(df1.groupby(['disciplina_ID','ano_disciplina'])['count_total'].count()).reset_index()
rep_periodo_count = pd.DataFrame(reprovados.groupby(['ano_disciplina', 'periodo_disciplina'])['count_rep_periodo'].count()).reset_index()
# Out:
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool

def getSource(disc):
    return ColumnDataSource(data = {
        'anos': [str(x) for x in reprovados_count[reprovados_count["disciplina_ID"] == disc]['ano_disciplina']],
        'reprovados': reprovados_count[reprovados_count["disciplina_ID"] == disc]['count_reprovados'],
        'aprovados' : aprovados_count[aprovados_count["disciplina_ID"] == disc]['count_aprovados'],
        'total' : total_count[total_count["disciplina_ID"] == disc]['count_total']
    }
)

def getFigure(disc):
    source = getSource(disc)
    p = figure(plot_width = 600, plot_height = 400, x_axis_label = 'Anos', y_axis_label = 'Número de alunos',
               x_range = source.data['anos'], title = 'Aprovados/Reprovados na Disciplina ' + str(disc))
    p.line(x = 'anos', y = 'reprovados', color = "red", line_width = 3, source = source, legend='Reprovados')
    p.circle(x = 'anos', y = 'reprovados', fill_color = "white", size = 7, source = source)
    p.line(x = 'anos', y = 'aprovados', color = "green",line_width = 3, source = source, legend='Aprovados')
    p.circle(x = 'anos', y = 'aprovados', fill_color = "white", size = 7, source=source)
    p.line(x = 'anos', y = 'total', color = "blue", line_width = 3, source = source, legend='Total')
    p.circle(x = 'anos', y = 'total', fill_color = "white", size = 7, source = source)
    p.legend.location = "top_left"
    return p

tab1 = Panel(child = getFigure(0), title = "Disciplina 0")
tab2 = Panel(child = getFigure(1), title = "Disciplina 1")
tab3 = Panel(child = getFigure(2), title = "Disciplina 2")
tab4 = Panel(child = getFigure(3), title = "Disciplina 3")
tab5 = Panel(child = getFigure(4), title = "Disciplina 4")
tab6 = Panel(child = getFigure(5), title = "Disciplina 5")
tab7 = Panel(child = getFigure(6), title = "Disciplina 6")
tabs = Tabs(tabs = [tab1, tab2, tab3, tab4, tab5, tab6, tab7])


output_notebook()
show(tabs)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d4d94b24-dcc9-4f9c-9011-e856d39ed30e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8489b244-65f5-442c-8569-da550df638cb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8489b244-65f5-442c-8569-da550df638cb").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8489b244-65f5-442c-8569-da550df638cb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8489b244-65f5-442c-8569-da550df638cb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ceab6d02-01d7-4192-86aa-4ecff6b5b5f0":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2e4df97b-103e-45c5-a918-dab1d35634e0","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"2e4df97b-103e-45c5-a918-dab1d35634e0","type":"BoxAnnotation"},"plot":{"id":"cb656dce-db4b-47c9-8f58-78da1b60ce41","subtype":"Figure","type":"Plot"}},"id":"8868980a-c4ca-48d5-bb62-da0bd62b4833","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"cb656dce-db4b-47c9-8f58-78da1b60ce41","subtype":"Figure","type":"Plot"}},"id":"5ee62c89-ab7d-44f0-aff1-af32b8bb457d","type":"SaveTool"},{"attributes":{"plot":{"id":"cb656dce-db4b-47c9-8f58-78da1b60ce41","subtype":"Figure","type":"Plot"}},"id":"99eb5275-f670-43ed-a110-91f8e09a4cdf","type":"ResetTool"},{"attributes":{"plot":{"id":"cb656dce-db4b-47c9-8f58-78da1b60ce41","subtype":"Figure","type":"Plot"}},"id":"3bf7ea94-699c-4e67-b49d-ced54d9d6dbf","type":"HelpTool"},{"attributes":{"items":[{"id":"6b8143c9-8727-48cb-b97d-5fa520915eba","type":"LegendItem"},{"id":"338620be-bcc7-4962-8901-fec3804ddeae","type":"LegendItem"},{"id":"d91cf9fe-1b99-4c7b-8feb-b58ff66cd388","type":"LegendItem"}],"location":"top_left","plot":{"id":"f613d20f-2c76-4468-a68b-6f2748ed5b2b","subtype":"Figure","type":"Plot"}},"id":"a0152d61-0bf8-4526-a19a-8e0bc3da3c85","type":"Legend"},{"attributes":{"label":{"value":"Reprovados"},"renderers":[{"id":"00da2a74-0add-4457-a995-a7714cc517ce","type":"GlyphRenderer"}]},"id":"e84633bb-cec8-4023-a65f-01041292f6e5","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"anos"},"y":{"field":"reprovados"}},"id":"39ed94e1-4881-435d-9a12-b602638a77ce","type":"Circle"},{"attributes":{"items":[{"id":"e84633bb-cec8-4023-a65f-01041292f6e5","type":"LegendItem"},{"id":"4e8377fd-b3ef-4d3c-8b9d-e33af2b0fabd","type":"LegendItem"},{"id":"5cd338c4-cb92-4ec8-875d-1f4d83a07f5b","type":"LegendItem"}],"location":"top_left","plot":{"id":"cb656dce-db4b-47c9-8f58-78da1b60ce41","subtype":"Figure","type":"Plot"}},"id":"e1416aa7-07a5-4584-a6e9-bc02ba461109","type":"Legend"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"anos"},"y":{"field":"reprovados"}},"id":"bb474e47-755a-4319-88ce-d1b1f76d2059","type":"Circle"},{"attributes":{"data_source":{"id":"4dc1507e-a2f2-42ef-b482-de48d3eef291","type":"ColumnDataSource"},"glyph":{"id":"bb474e47-755a-4319-88ce-d1b1f76d2059","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"39ed94e1-4881-435d-9a12-b602638a77ce","type":"Circle"},"selection_glyph":null},"id":"3f25f09c-cb21-4f76-832f-eef5187d5986","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"anos"},"y":{"field":"aprovados"}},"id":"97801b61-7ee6-473a-8a2e-51c966774855","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"anos"},"y":{"field":"aprovados"}},"id":"e7621f01-0e5a-44c8-8b3c-f33ca6678b11","type":"Circle"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":3},"x":{"field":"anos"},"y":{"field":"aprovados"}},"id":"aceabd85-1c45-4e87-9ad6-4c32eee947ae","type":"Line"},{"attributes":{"data_source":{"id":"4dc1507e-a2f2-42ef-b482-de48d3eef291","type":"ColumnDataSource"},"glyph":{"id":"aceabd85-1c45-4e87-9ad6-4c32eee947ae","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"97801b61-7ee6-473a-8a2e-51c966774855","type": ...

# %% [markdown]
# ## Análise 9 - Evolução temporal dos períodos
#
# Nesta seção utilizamos a quantidade de reprovados para mostrar o desenvolvimento dos períodos no decorrer dos anos para determinar se os períodos estão equilibrados.
#
# Entre 2014 e 2015 os períodos seguiam a mesma tendência e o 2º Período se apresentava como mais desafiador aos alunos. Todavia, em 2016 o 1º Período teve um grande salto no número de reprovados (reprovou mais de 400 alunos a mais do que no ano anterior) e passou a ser, momentaneamente, o semestre mais desafiador. Essa tendência de um ano de 2016 mais complicado para os alunos já foi notada em análises anteriores que apresentaram altos níveis de reprovação nas disciplinas 2, 3, 5 e 6.
#
# O 2º Período manteve sua tendência.

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool

source = ColumnDataSource(data = {
        'anos': [str(x) for x in rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 1]['ano_disciplina']],
        'reprovados1': rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 1]['count_rep_periodo']
    }
)

source2 = ColumnDataSource(data = {
        'anos': [str(x) for x in rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 2]['ano_disciplina']],
        'reprovados2' : rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 2]['count_rep_periodo']
    }
)

p = figure(plot_width = 600, plot_height = 400, x_axis_label = 'Anos', y_axis_label = 'Número de alunos',
           x_range = source.data['anos'], title = 'Reprovados por período')
p.line(x = 'anos', y = 'reprovados1', color = "purple", line_width = 3, source = source, legend='1º Período')
p.circle(x = 'anos', y = 'reprovados1', fill_color = "white", size = 7, source = source)
p.line(x = 'anos', y = 'reprovados2', color = "orange",line_width = 3, source = source2, legend='2º Período')
p.circle(x = 'anos', y = 'reprovados2', fill_color = "white", size = 7, source=source2)
p.legend.location = "top_left"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4156b93c-dd36-4fbf-b5b2-33fbb400d208">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0f0f5c78-a5ab-49c3-b930-d9acb33906e3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0f0f5c78-a5ab-49c3-b930-d9acb33906e3").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0f0f5c78-a5ab-49c3-b930-d9acb33906e3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0f0f5c78-a5ab-49c3-b930-d9acb33906e3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cbbc92de-3838-479e-a23a-8bee5a17f163":{"roots":{"references":[{"attributes":{"below":[{"id":"81914ac8-3c33-4739-97e2-40c8f78b0515","type":"CategoricalAxis"}],"left":[{"id":"42e5a5bd-01a4-46e7-8bb0-5e653b966f29","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"81914ac8-3c33-4739-97e2-40c8f78b0515","type":"CategoricalAxis"},{"id":"05f0e79e-5982-4dc4-b866-ae659dcb02dc","type":"Grid"},{"id":"42e5a5bd-01a4-46e7-8bb0-5e653b966f29","type":"LinearAxis"},{"id":"7a36ff3d-e467-4aba-9ffb-914945734aea","type":"Grid"},{"id":"b6b9e92e-8d68-40e4-96cd-2b73ff3df951","type":"BoxAnnotation"},{"id":"da3d5bab-86cb-4b90-9f8a-305eb9d5e3e3","type":"Legend"},{"id":"d79704c3-0a19-4d28-9b83-5b180e60e7de","type":"GlyphRenderer"},{"id":"039ac930-5e0f-4bab-b570-b4b88395ce6d","type":"GlyphRenderer"},{"id":"1e784156-be30-4c45-8941-8a1cda29393a","type":"GlyphRenderer"},{"id":"b240c963-92e7-4d5c-9b82-291cf6505ea2","type":"GlyphRenderer"}],"title":{"id":"8c6ab04e-d44e-496f-808f-fe42920d0d0c","type":"Title"},"tool_events":{"id":"669048b4-2778-4c91-b8dc-96666b2172cb","type":"ToolEvents"},"toolbar":{"id":"b7ad5cee-6967-478f-927e-bb7ecf2306db","type":"Toolbar"},"x_range":{"id":"a800fd98-83af-4bd7-bc7e-9303025e1749","type":"FactorRange"},"y_range":{"id":"437f1409-f80b-4b91-b3d8-0fe1e9dc69f9","type":"DataRange1d"}},"id":"01d42dd2-1df8-499d-b5a7-b7566bfe05c2","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"anos"},"y":{"field":"reprovados2"}},"id":"243ffcbe-c8d5-40eb-b478-19cbc8302894","type":"Circle"},{"attributes":{"callback":null,"column_names":["anos","reprovados1"],"data":{"anos":["2014","2015","2016"],"reprovados1":[117,195,627]}},"id":"1bc1f732-c340-4b01-825e-a3604e4442ae","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1bc1f732-c340-4b01-825e-a3604e4442ae","type":"ColumnDataSource"},"glyph":{"id":"e99be14d-abf4-4167-8192-f7eb7bbf7851","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"05dbd708-9dec-4919-ae3f-4402710fa8d7","type":"Circle"},"selection_glyph":null},"id":"039ac930-5e0f-4bab-b570-b4b88395ce6d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["anos","reprovados2"],"data":{"anos":["2014","2015","2016"],"reprovados2":[246,358,455]}},"id":"7640c8e4-0d6f-4a01-8085-4bb94a0f502d","type":"ColumnDataSource"},{"attributes":{"axis_label":"Anos","formatter":{"id":"ce4cab90-c88d-4309-abec-1f999275f775","type":"CategoricalTickFormatter"},"plot":{"id":"01d42dd2-1df8-499d-b5a7-b7566bfe05c2","subtype":"Figure","type":"Plot"},"ticker":{"id":"b7471062-fd68-414e-bbb5-89a673fc4884","type":"CategoricalTicker"}},"id":"81914ac8-3c33-4739-97e2-40c8f78b0515","type":"CategoricalAxis"},{"attributes":{"plot":null,"text":"Reprovados por per\u00edodo"},"id":"8c6ab04e-d44e-496f-808f-fe42920d0d0c","type":"Title"},{"attributes":{"line_color":{"value":"purple"},"line_width":{"value":3},"x":{"field":"anos"},"y":{"field":"reprovados1"}},"id":"0bd9e307-613a-441b-a4da-dc95e6986e84","type":"Line"},{"attributes":{},"id":"651fe4f5-94e5-46ee-97ca-f16b121efedf","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"37b7c2fc-e069-40c7-9af9-d658b610fa75","type":"PanTool"},{"id":"6de14c1e-8bd7-4955-a28d-d1af9d393690","type":"WheelZoomTool"},{"id":"a44c7308-d408-4110-987a-16ace7aae365","type":"BoxZoomTool"},{"id":"02e20ddd-dd01-4148-b633-93c9f13e401f","type":"SaveTool"},{"id":"d668f10b-e48c-4d0d-b4ba-ac5c9b085c39","type":"ResetTool"},{"id":"fe54f5f3-0a26-4026-9af3-8453b39ddd0d","type":"HelpTool"}]},"id":"b7ad5cee-6967-478f-927e-bb7ecf2306db","type":"Toolbar"},{"attributes":{"callback":null,"factors":["2014","2015","2016"]},"id":"a800fd98-83af-4bd7-bc7e-9303025e1749","type":"FactorRange"},{"attributes":{"callback":null},"id":"437f1409-f80b-4b91-b3d8-0fe1e9dc69f9","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"l ...

# %% [markdown]
# ## Análise 10 - Evolução temporal dos alunos que cancelaram ou trancaram
#
# Nesta seção analisamos a quantidade de alunos que cancelaram ou trancaram no decorrer dos anos, para tentar fazer um paralelo com análises anteriores, principalmente as que envolvem número de reprovações.
#
# Percebe-se que o número de alunos que cancelaram ou trancaram cresceu além da tendência dos anos anteriores. Isso deve ter sido incentivado pelo baixo desempenho dos alunos naquele ano.

# %%
df2 = data[data['ano_disciplina'] != 2017]
df2['count_cancelado'] = 0
df2['count_trancado'] = 0

cancelado = df2[df2["status"] == "CANCELADO"]
trancado = df2[df2["status"] == "TRANCADO"]

cancelado_count = pd.DataFrame(cancelado.groupby(['a_ID','ano_disciplina'])['count_cancelado'].count()).reset_index()
trancado_count = pd.DataFrame(trancado.groupby(['a_ID','ano_disciplina'])['count_trancado'].count()).reset_index()

cancelado_dic = {}
trancado_dic = {}

for ind in set(cancelado_count['a_ID']):
    a = cancelado_count[cancelado_count['a_ID'] == ind]['ano_disciplina'].tail(1)
    if str(int(a)) in cancelado_dic:
        cancelado_dic[str(int(a))] += 1
    else:
        cancelado_dic[str(int(a))] = 1
        
for ind in set(trancado_count['a_ID']):
    a = trancado_count[trancado_count['a_ID'] == ind]['ano_disciplina'].tail(1)
    if str(int(a)) in trancado_dic:
        trancado_dic[str(int(a))] += 1
    else:
        trancado_dic[str(int(a))] = 1
# Out:
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.palettes import Spectral6

source1 = ColumnDataSource(data = {
        'anos': [str(x) for x in sorted(cancelado_dic.keys())],
        'cancelado': [cancelado_dic[x] for x in sorted(cancelado_dic.keys())]
    }
)

source2 = ColumnDataSource(data = {
        'anos': [str(x) for x in sorted(trancado_dic.keys())],
        'trancado': [trancado_dic[x] for x in sorted(trancado_dic.keys())]
    }
)


p = figure(plot_width = 600, plot_height = 400, x_axis_label = 'Anos', y_axis_label = 'Número de alunos',
           x_range = source.data['anos'], title = 'Situação dos alunos')

p.line(x = 'anos', y = 'cancelado', color = Spectral6[0], line_width = 3, source = source1, legend = 'Cancelado')
p.circle(x = 'anos', y = 'cancelado', fill_color = "white", size = 7, source = source1)

p.line(x = 'anos', y = 'trancado', color = Spectral6[1], line_width = 3, source = source2, legend='Trancado')
p.circle(x = 'anos', y = 'trancado', fill_color = "white", size = 7, source=source2)
p.legend.location = "top_left"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="24525328-34c9-4922-a8b9-e1e0d419009e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="70351bec-bd67-4a38-8ffa-2413ef367699"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("70351bec-bd67-4a38-8ffa-2413ef367699").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("70351bec-bd67-4a38-8ffa-2413ef367699");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '70351bec-bd67-4a38-8ffa-2413ef367699' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"afa71807-7f7a-4ab2-bf4c-c50e86fa7abb":{"roots":{"references":[{"attributes":{},"id":"eea7de2e-699a-423b-b02f-1381258fbc54","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1be0f081-e103-4149-bb9b-db3eb0fe4396","type":"PanTool"},{"id":"08d49b13-223b-4d72-9199-f1491018637a","type":"WheelZoomTool"},{"id":"aa574a5e-ce5a-4c4a-9e9d-31b0f453003a","type":"BoxZoomTool"},{"id":"2c43da15-d627-4324-83c1-091dcc93f15e","type":"SaveTool"},{"id":"e760fcf9-014e-4ec4-ad8b-29592d174728","type":"ResetTool"},{"id":"f4993013-6f36-4f43-ab11-583bfb9a876f","type":"HelpTool"}]},"id":"ad632f0c-beb2-48f1-a96d-2fd92992cbd2","type":"Toolbar"},{"attributes":{"callback":null},"id":"2cea36ff-4b52-4e3a-8ef3-2daed52dedc0","type":"DataRange1d"},{"attributes":{"label":{"value":"Cancelado"},"renderers":[{"id":"5179a53e-066c-4bd2-aeb6-6b86631651fe","type":"GlyphRenderer"}]},"id":"ed77a7e6-0342-46f9-bbc1-9dcc43bc5dd7","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"anos"},"y":{"field":"cancelado"}},"id":"8b9012c8-4a84-446b-a437-dec34136573d","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f8089ab0-ab63-47e1-91d8-0ddfaf127087","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"157653d3-5950-4958-ad5b-25e2602c022e","subtype":"Figure","type":"Plot"}},"id":"e760fcf9-014e-4ec4-ad8b-29592d174728","type":"ResetTool"},{"attributes":{"plot":{"id":"157653d3-5950-4958-ad5b-25e2602c022e","subtype":"Figure","type":"Plot"}},"id":"2c43da15-d627-4324-83c1-091dcc93f15e","type":"SaveTool"},{"attributes":{"label":{"value":"Trancado"},"renderers":[{"id":"3ce59723-6d2f-46ca-a76e-ca1983823363","type":"GlyphRenderer"}]},"id":"0c86c958-be75-49a3-8bab-c586106eb37d","type":"LegendItem"},{"attributes":{},"id":"825c7f33-7b9a-4f2f-a229-e43eaddded78","type":"BasicTicker"},{"attributes":{"data_source":{"id":"c04dee96-1b21-4b0b-b355-07f75b7772a3","type":"ColumnDataSource"},"glyph":{"id":"8298f9eb-f410-492e-976c-e2c60600086b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1a3e3c0e-c1b6-4ad3-be81-1b7672da6197","type":"Circle"},"selection_glyph":null},"id":"b5304b57-33ad-4be9-a0de-7ad38c776c3f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"anos"},"y":{"field":"cancelado"}},"id":"1a3e3c0e-c1b6-4ad3-be81-1b7672da6197","type":"Circle"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"anos"},"y":{"field":"cancelado"}},"id":"8298f9eb-f410-492e-976c-e2c60600086b","type":"Circle"},{"attributes":{"overlay":{"id":"f8089ab0-ab63-47e1-91d8-0ddfaf127087","type":"BoxAnnotation"},"plot":{"id":"157653d3-5950-4958-ad5b-25e2602c022e","subtype":"Figure","type":"Plot"}},"id":"aa574a5e-ce5a-4c4a-9e9d-31b0f453003a","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"c04dee96-1b21-4b0b-b355-07f75b7772a3","type":"ColumnDataSource"},"glyph":{"id":"143652ac-9a54-44f9-be88-95434d52e358","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8b9012c8-4a84-446b-a437-dec34136573d","type":"Line"},"selection_glyph":null},"id":"5179a53e-066c-4bd2-aeb6-6b86631651fe","type":"GlyphRenderer"},{"attributes":{},"id":"d07e931c-b0e0-4bf3-ad5f-755c572ff040","type":"CategoricalTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"anos"},"y":{"field":"trancado"}},"id":"202e9cc8-420b-4d12-a02f-59a636b72afc","type":"Line"},{"attributes":{"d ...
