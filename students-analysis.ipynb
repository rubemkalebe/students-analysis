# %% [markdown]
# #### Load and prepare data:

# %%
# Import pandas, plotly and bokeh.
import pandas as pd
import plotly.plotly as py
from bokeh.plotting import figure,ColumnDataSource
from bokeh.io import output_notebook, show
from bokeh.models import HoverTool, NumeralTickFormatter
from bokeh.layouts import gridplot
from bokeh.charts import Histogram, Bar, output_file, Scatter,BoxPlot, output_file, show


# Assign spreadsheet filename: file
file = 'imd_student_blind.xlsx'

# Load spreadsheet: xl
xl = pd.ExcelFile(file)

# Print sheet names
print(xl.sheet_names)

# Load the sheet into a DataFrame by index: data
data = xl.parse(0)
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,wheel_zoom, pan'
# Out:
# ['Sheet1']

# %%
# Print the head of the DataFrame data
data.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota
# 0          0           640      618.0
# 1          0           640      618.0
# 2          0           660      615.0
# 3          0           560      600.0
# 4          0           760      673.0

# %%
source = ColumnDataSource(data)
data['count'] = 0
data.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota  count
# 0          0           640      618.0      0
# 1          0           640      618.0      0
# 2          0           660      615.0      0
# 3          0           560      600.0      0
# 4          0           760      673.0      0

# %%
d = data[data["status.disciplina"] == "Reprovado"]
df1 = pd.DataFrame(d.groupby(['disciplina_ID','ano_disciplina'])['count'].count()).reset_index()
df1.head(10)
# Out:
#    disciplina_ID  ano_disciplina  count
# 0              0            2014     73
# 1              0            2015    105
# 2              0            2016    143
# 3              1            2014     35
# 4              1            2015     29
# 5              1            2016     42
# 6              1            2017      3
# 7              2            2014     47
# 8              2            2015     47
# 9              2            2016    229

# %%
dataYear2014_ID = df1[df1["ano_disciplina"] == 2014]["disciplina_ID"]
dataYear2014_count = df1[df1["ano_disciplina"] == 2014]["count"]


dataYear2015_ID = df1[df1["ano_disciplina"] == 2015]["disciplina_ID"]
dataYear2015_count = df1[df1["ano_disciplina"] == 2015]["count"]

dataYear2016_ID = df1[df1["ano_disciplina"] == 2016]["disciplina_ID"]
dataYear2016_count = df1[df1["ano_disciplina"] == 2016]["count"]

dataYear2016_count.head(100)
# Out:
# 2     143
# 5      42
# 9     229
# 12    178
# 15     58
# 19    253
# 22    179
# Name: count, dtype: int64

# %%
#source = ColumnDataSource(df1)

Reprovados_Disc2014 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2014', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])
Reprovados_Disc2015 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2015', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])
Reprovados_Disc2016 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2016', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])


Reprovados_Disc2014.circle(dataYear2014_ID,dataYear2014_count,size=10,color = 'green')
Reprovados_Disc2015.circle(dataYear2015_ID,dataYear2015_count,size=10,color = 'navy')
Reprovados_Disc2016.circle(dataYear2016_ID,dataYear2016_count,size=10,color = 'red')
# Out:
# GlyphRenderer(id='38f8cf22-59b5-4560-bfd0-831a2800e724', ...)

# %% [markdown]
# ## Análise 1 - Número de Reprovados x Disciplina em cada ano.
#
# Nesta seção utilizamos os dados do número de reprovados em cada uma das disciplinas disponíveis, pelos anos em que elas foram ofertadas.
#
# "Há um sistema pré-estabelecido ao qual o aluno precisa se adaptar, se inserir, como um ritual de passagem. Quem não for capaz de cumprir etapas estabelecidas pela coordenação da disciplina, provavelmente, será reprovado.”
#
# #### Fabiana Colombo Garzella,
# **A disciplina de Cálculo I: a análise das relações entre as práticas pedagógicas do professor e seus impactos nos alunos**
#
# O Número de reprovados em algumas disciplinas do Curso do Bacharelado em Tecnologia da Informação, tem crescido rapidamente e é algo que deve ser revisado. Pensando nisso resolvemos analisar o número de reprovados em cada uma das disciplinas disponíveis, pelos anos em que elas foram ofertadas.
#
# Como visto, algumas disciplinas, a cada ano, tem seu número de reprovações aumentando. Além de outros possíveis fatores, a forma como a disciplina está sendo ofertada, a relação do aluno com os professores ou a quantidade de alunos em uma única turma, deve ser revisada pela coordenação ou setor pedagógico.
# Nos gráficos, podemos destacar a disciplina 5, que a cada ano aumenta o número de reprovados, chegando a 2016 com mais de 250 reprovações naquele ano. A disciplina 2, apesar de ter mantido esse valor de 2014 para 2015 com cerca de 50, teve em torno de 230 reprovações em 2016. A disciplina 3 também teve um aumento considerável, já que em 2014 o valor era de aproximadamente 50 para em torno de 180 em 2016.

# %%
row1 = [Reprovados_Disc2014,Reprovados_Disc2015]

# Create a list containing plots p3 and p4: row2
row2 = [Reprovados_Disc2016]

layout = gridplot([row1,row2],plot_width=450, plot_height=450)

#output_notebook()
output_file("analise1.html")

# Display the plot
show(layout)

# %% [markdown]
# ## Análise 2 - Número de Reprovados x Disciplina em todos os anos.
#
# Nesta seção utilizamos os dados do número de reprovados em cada uma das disciplinas disponíveis, em todos os anos.
#
# "Entre os fatores determinantes para esse quadro, a pesquisa relaciona o grande número de alunos por turma, impedindo que necessidades particulares de determinados grupos de alunos sejam atendidas. No caso do semestre observado, existiam 30 turmas da disciplina, com média de 40 alunos cada. Três turmas eram agrupadas em uma sala de aula, totalizando aproximadamente 150 alunos. No conjunto, havia 10 salas composta por três turmas, cada uma com um professor responsável."
#
# #### Fabiana Colombo Garzella,
# **A disciplina de Cálculo I: a análise das relações entre as práticas pedagógicas do professor e seus impactos nos alunos**
#
# Como podemos ver abaixo, o crescente número de reprovados também pode ser influenciado pela necessidade de compensar alunos reprovados em semestres anteriores, aumentando a quantidade de de alunos por turma e consequentemente, a necessidade de abrir mais turmas para as diciplinas.
# No gráfico, podemos ver a disciplina 5 com um total de mais de 500 reprovados somandos todas as suas ofertas desde o ano de 2014 até o ano de 2016. Enquanto outras disciplinas, não menos importantes tem um valor considerevável com algo em torno de 320 reprovações. As disciplinas 1 e 4 possuem o menor número, com cerca de 120 e 160 respectivamente.

# %%
#from bokeh.plotting import figure, output_file, show

#mypalette = Spectral11[0:10]
#source = ColumnDataSource(df1)

#df1.plot(kind = 'line')
Bar_Reprovados = Bar(df1, 'disciplina_ID', values='count',color = 'disciplina_ID', xlabel="Disciplina",  
         ylabel = "Nº de Reprovados", title="Disciplinas pelo Nº de Reprovados", 
         legend = 'top_right', width = 10,tools=[TOOLS])

output_notebook()
show(Bar_Reprovados)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aad72502-1793-4e63-998e-4d2207c8f2f2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b5b4cf0b-b2d9-4938-a82d-9e5cce8bb8cb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b5b4cf0b-b2d9-4938-a82d-9e5cce8bb8cb").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b5b4cf0b-b2d9-4938-a82d-9e5cce8bb8cb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b5b4cf0b-b2d9-4938-a82d-9e5cce8bb8cb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a6ddb96b-3cf9-4ec8-ae77-037695e12323":{"roots":{"references":[{"attributes":{"callback":null,"factors":["0","1","2","3","4","5","6"]},"id":"67784600-57d8-4a69-8de2-f7c2a95366b9","type":"FactorRange"},{"attributes":{"label":{"value":"6"},"renderers":[{"id":"be165a86-d3ca-425e-89c4-00c7ac2d0c3d","type":"GlyphRenderer"}]},"id":"b5038ac8-64a6-4b97-989b-bfc55adfa182","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6746c64b-5d2c-4146-b6ec-a3f7ad38e9b0","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"07590b02-c13b-4482-b96a-346e54ef22f2","type":"ColumnDataSource"},"glyph":{"id":"bca683b3-76e7-4f93-871f-6a3105b2b0c3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"78c2755b-1234-4ed3-a86d-b04c897ce029","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":549.15},"id":"96da86d0-f4d1-46a9-830b-79d8e3831ece","type":"Range1d"},{"attributes":{"overlay":{"id":"6746c64b-5d2c-4146-b6ec-a3f7ad38e9b0","type":"BoxAnnotation"},"plot":{"id":"dcd33203-79e5-4ecb-83f9-d348832e1a2e","subtype":"Chart","type":"Plot"}},"id":"9d5a6174-205e-43fd-b740-0bbc5dc691da","type":"BoxZoomTool"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"78c2755b-1234-4ed3-a86d-b04c897ce029","type":"GlyphRenderer"}]},"id":"783024e1-e670-40e7-9cad-8cb861a38f1d","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9d5a6174-205e-43fd-b740-0bbc5dc691da","type":"BoxZoomTool"},{"id":"c06a59e3-bac5-438d-ad84-6081b47cdeef","type":"BoxSelectTool"},{"id":"b0d8a805-5aa9-4490-8516-36f090b0bb0f","type":"CrosshairTool"},{"id":"290e9647-bc0e-4eca-ab34-cab46820c391","type":"ResizeTool"},{"id":"2c21d763-c4b4-457d-b7dc-d57c4edcee0b","type":"ResetTool"},{"id":"01064605-3405-4e83-a1aa-3d5c7f1dbb27","type":"WheelZoomTool"},{"id":"3fab00c7-4d1b-4d38-8e83-b21d80b5640d","type":"PanTool"}]},"id":"1175fb9e-1cd2-4ce5-8e94-ea8e3af04e2d","type":"Toolbar"},{"attributes":{},"id":"733c82dc-825a-4ddd-bb08-e3e00d97836d","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba145ec9-86c9-46f2-9fdf-a8fb46a69bf4","type":"Rect"},{"attributes":{"label":{"value":"2"},"renderers":[{"id":"f3309274-c6b0-4d50-9f4f-c78338f63fa0","type":"GlyphRenderer"}]},"id":"ba4853ea-92fb-4a9e-844a-3f4e17247b23","type":"LegendItem"},{"attributes":{"callback":null,"overlay":{"id":"3e9742cd-7f55-4244-825a-b359919ec7a6","type":"BoxAnnotation"},"plot":{"id":"dcd33203-79e5-4ecb-83f9-d348832e1a2e","subtype":"Chart","type":"Plot"}},"id":"c06a59e3-bac5-438d-ad84-6081b47cdeef","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"dcd33203-79e5-4ecb-83f9-d348832e1a2e","subtype":"Chart","type":"Plot"}},"id":"b0d8a805-5aa9-4490-8516-36f090b0bb0f","type":"CrosshairTool"},{"attributes":{"plot":{"id":"dcd33203-79e5-4ecb-83f9-d348832e1a2e","subtype":"Chart","type":"Plot"}},"id":"290e9647-bc0e-4eca-ab34-cab46820c391","type":"ResizeTool"},{"attributes":{"plot":{"id":"dcd33203-79e5-4ecb-83f9-d348832e1a2e","subtype":"Chart","type":"Plot"}},"id":"2c21d763-c4b4-457d-b7dc-d57c4edcee0b","type":"ResetTool"},{"attributes":{"plot":{"id":"dcd33203-79e5-4ecb-83f9-d348832e1a2e","subtype":"Chart","type":"Plot"}},"id":"01064605-3405-4e83-a1aa-3d5c7f1dbb27","type":"WheelZoomTool"},{"attributes":{"label":{"value":"4"},"renderers":[{"id":"8d6d9c30-9437-4623-8f86-454594431f3d","type":"GlyphRenderer"}]},"id":"efbbd340-f738-47f7-90e1-329ca33f02c6","type":"LegendItem"},{"attributes":{"plot":{"id":"dcd33203-79e5-4ecb ...

# %%
data2 = data
data2['count'] = 0
data2.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota  count
# 0          0           640      618.0      0
# 1          0           640      618.0      0
# 2          0           660      615.0      0
# 3          0           560      600.0      0
# 4          0           760      673.0      0

# %%
dataYear2014_nota = data2[data2["ano_disciplina"] == 2014]
dataYear2015_nota = data2[data2["ano_disciplina"] == 2015]
dataYear2016_nota = data2[data2["ano_disciplina"] == 2016]

# %%
NotasYear2014 = BoxPlot(dataYear2014_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID', legend = False, 
             title = "BoxPlot das disciplinas pelas notas, Ano 2014", tools = [TOOLS])

NotasYear2015 = BoxPlot(dataYear2015_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2015", tools = [TOOLS])

NotasYear2016 = BoxPlot(dataYear2016_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2016", tools = [TOOLS])

# %% [markdown]
# ## Análise 3 - Disciplinas x Notas em cada ano.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# "Pesquisas recentes têm observado que muitos fatores podem influenciar o desempenho de um estudante: conhecimentos anteriores, infraestrutura (materiais adequados e espaço físico para estudar), emocionais (estresse e autoconfiança), desempenho do professor (didática, pontualidade, provas em nível adequado e indicação de literatura apropriada) e esforço pessoal do estudante (estar presente nas aulas, prestar atenção, tirar dúvidas, estudar em casa e saber administrar o tempo)."
#
# #### Cesar Duarte Souto-Maior, José Alonso Borba, Paulo de Souza Knupp, Eva de Souza Croll
# **Análise de Fatores que Afetam o Desempenho de Alunos de Graduação em Administração e Contabilidade na Disciplina de Pesquisa Operacional**
#
# Analisando as disciplinas, no ano de 2014, podemos ver as disciplinas 3 e 5, com medianas em 2,2 e 2,9 respectavemente, que consideram o valor da média final da maioria dos alunos. Mas enquanto a disciplina 3 se mantém com o mesmo valor no decorrer dos anos, a disciplina 5 em 2016 teve como mediana 1,8 e cerca de 50% dos alunos com nota final igual ou inferior a 4,1.
# As disciplinas 1, 2 e 4 matém os mesmos níveis de distribuições no decorrer dos anos. A disciplina 6 teve uma distribuição menos concentrada nos anos de 2015 e 2016.

# %%
row1 = [NotasYear2014,NotasYear2015]

# Create a list containing plots p3 and p4: row2
row2 = [NotasYear2016]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1f77c684-36c5-4ce9-bec4-b452ec97a0e0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="89fbb700-ac3a-4af5-bdce-c23fbc769995"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("89fbb700-ac3a-4af5-bdce-c23fbc769995").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("89fbb700-ac3a-4af5-bdce-c23fbc769995");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '89fbb700-ac3a-4af5-bdce-c23fbc769995' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"46260d99-fa89-4edb-98c2-f9502544a4ca":{"roots":{"references":[{"attributes":{},"id":"fa7c91fe-b17a-41e4-87e2-93e5605159de","type":"BasicTicker"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"2f9a31b4-4e5f-4fc7-9527-5a565459828d","type":"Segment"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3c976a97-bdd5-4495-8abf-b5a93b2772e1","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"3a4df8ae-35f6-465f-82c2-b4d42ec83595","type":"Segment"},{"attributes":{"axis_label":"Disciplina_Id","formatter":{"id":"58cd9656-e85c-40f7-82d2-a7ad5cce8596","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"f177dce3-a2e9-4654-907f-70e4010a9d98","subtype":"Chart","type":"Plot"},"ticker":{"id":"9130ffeb-709b-4fe0-8b35-0a1e7d23ffa0","type":"CategoricalTicker"}},"id":"c53046ee-68fd-47ae-b414-deb7b3749d6d","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"5ea40235-2a86-41d9-ab3c-196703024f05","type":"ColumnDataSource"},"glyph":{"id":"f8a86d41-76ba-43ad-b153-35ae5f0403d3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"84454875-5050-4357-aec8-7d10b4bb50f7","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"f177dce3-a2e9-4654-907f-70e4010a9d98","subtype":"Chart","type":"Plot"},"ticker":{"id":"fa7c91fe-b17a-41e4-87e2-93e5605159de","type":"BasicTicker"}},"id":"2ee605a4-0825-4575-83c7-c9110e7a7d78","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":1}],"color":["#5ab738"],"disciplina_ID":[1],"fill_alpha":[0.8],"height":[1.1000000000000005],"label":[{"disciplina_ID":1}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["1"],"y":[6.65]}},"id":"8d72391d-acb8-472b-95af-11f26a2aeeab","type":"ColumnDataSource"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"440a35d4-f714-4958-9469-3504e5462252","type":"Segment"},{"attributes":{"data_source":{"id":"84bd13db-683b-4562-a296-1d97ca65ff85","type":"ColumnDataSource"},"glyph":{"id":"3a4df8ae-35f6-465f-82c2-b4d42ec83595","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cb90c002-dff5-4af4-b3f4-c58c22a84cbd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d33b9846-6cd3-4bd4-aaca-4d2b2afdd9e5","type":"ColumnDataSource"},"glyph":{"id":"440a35d4-f714-4958-9469-3504e5462252","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"55b0c671-b6c1-4cac-bad4-50fa67e6935e","type":"GlyphRenderer"},{"attributes":{"axis_label":"Nota","formatter":{"id":"94084867-d61d-416f-a36d-8137972f6fe8","type":"BasicTickFormatter"},"plot":{"id":"f177dce3-a2e9-4654-907f-70e4010a9d98","subtype":"Chart","type":"Plot"},"ticker":{"id":"fa7c91fe-b17a-41e4-87e2-93e5605159de","type":"BasicTicker"}},"id":"18aa68f9-882a-46fd-921d-855ddc3c7039","type":"LinearAxis"},{"attributes":{"data_source":{"id":"c1ee2adc-7485-489b-a816-6963a2151601","type":"ColumnDataSource"},"glyph":{"id":"2f9a31b4-4e5f-4fc7-9527-5a565459828d","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b81d6d0a-cfdb-4b5f-9932-00437d1e414f","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"bae847bc-84aa-4748-b59a-2075f370a716","type":"Segment"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart ...

# %% [markdown]
# ## Análise 4 - Disciplinas x Notas em todos os anos.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# Analisando as disciplinas, podemos ver as disciplinas 3 e 5, com quase 50% de seus alunos com médias abaixo de 5.
# As disciplinas 1 e 4 matém os mesmos níveis de distribuições, olhando para o fato de terem vários Outliers. A disciplina 6 teve uma distribuição menos concentrada com mediana aproximadamente em 4 e as disciplinas 0 e 2 com valores próximos a 5,2.

# %%
BoxPlot_Nota = BoxPlot(data, values='nota', label='disciplina_ID', legend = 'top_right', color = 'disciplina_ID', tools = [TOOLS])

output_notebook()


show(BoxPlot_Nota)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="21b74630-bc03-4f93-bbe6-60e5d841e3fc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e4f59230-94a6-4f26-a74b-90f63b58fb0f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e4f59230-94a6-4f26-a74b-90f63b58fb0f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e4f59230-94a6-4f26-a74b-90f63b58fb0f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e4f59230-94a6-4f26-a74b-90f63b58fb0f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1a58ef7b-89a0-4c47-afe4-0ab107ae9237":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bf5383f2-bfb2-4763-847a-58f5049c4448","type":"BoxAnnotation"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"21bd880a-2c0d-4546-aabd-c860d2c9e3fd","type":"Segment"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":6}],"color":["#f22c40"],"disciplina_ID":[6],"fill_alpha":[0.8],"height":[3.3],"label":[{"disciplina_ID":6}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["6"],"y":[2.65]}},"id":"5dca7b06-4258-434a-8c11-388e48e937d6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a108efd9-e3e7-4a0e-8955-26c788bfe924","type":"ColumnDataSource"},"glyph":{"id":"69b29255-86f8-497e-b089-f3e7d2b6bd34","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"41839d4b-5e6b-4e1e-b48c-ea06c0c43bac","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"a4242db6-a653-43c2-bc53-9458557ab0d4","type":"Segment"},{"attributes":{"data_source":{"id":"6555a2dc-0afa-462b-80ba-eedb08f23ac2","type":"ColumnDataSource"},"glyph":{"id":"f7c8cec6-86e5-40ea-86ff-969e01bddbcb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ae8985f9-2e3a-478b-9ff8-51091749ee1a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3db63e30-9b7e-4e9b-8eb1-38b6374155a7","type":"ColumnDataSource"},"glyph":{"id":"467502b0-fddd-43d8-957a-2e95542b888b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"961df2c7-c308-4ca0-87a9-7fddf88cb838","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":10.5},"id":"95c23068-9bd4-4286-86f5-3274381dd588","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":1}],"color":["#5ab738"],"disciplina_ID":[1],"fill_alpha":[0.8],"height":[1.0999999999999996],"label":[{"disciplina_ID":1}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["1"],"y":[6.55]}},"id":"6555a2dc-0afa-462b-80ba-eedb08f23ac2","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":2}],"color":["#407ee7"],"disciplina_ID":[2],"fill_alpha":[0.8],"height":[1.4000000000000004],"label":[{"disciplina_ID":2}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["2"],"y":[6.0]}},"id":"3db63e30-9b7e-4e9b-8eb1-38b6374155a7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2b3c8dbe-a12f-4084-876a-4e9b56e37e45","type":"Rect"},{"attributes":{"items":[{"id":"17338bbf-aa23-4fcc-a87b-ef1eff08e80f","type":"LegendItem"},{"id":"beed48e2-e27a-458b-a350-c82688900267","type":"LegendItem"},{"id":"498f9262-f77f-4e9e-93e2-885d6ae15080","type":"LegendItem"},{"id":"2d62a05c-7458-4964-95f0-c42e5a9b0659","type":"LegendItem"},{"id":"47e89abc-0aa7-4248-8180-3fb3ac3b7b60","type":"LegendItem"},{"id":"37a984ad-038a-42b5-9c44-b02e077a0df2","type":"LegendItem"},{"id":"c0270ed4-65ba-42e3-be4f-8a1c60e2112c","type":"LegendItem"}],"plot":{"id":"38838708-0398-4364 ...

# %%
Notas_Enem2014 = BoxPlot(data, values='enen-nota', label='ano_ingresso', color = 'ano_ingresso', legend = 'bottom_right', 
             title = "BoxPlot Notas do Enem pelo Ano de Ingresso", tools = [TOOLS])

Notas_Enem2015 = BoxPlot(data, values='enem-redacao', label='ano_ingresso', color = 'ano_ingresso', legend = 'bottom_right', 
             title = "BoxPlot Notas da Redação Enem pelo Ano de Ingresso", tools = [TOOLS])
Notas_Enem2016 = BoxPlot(data, values='enem-matematica', label='ano_ingresso', color = 'ano_ingresso', legend = False, 
             title = "BoxPlot Notas de Matemática Enem pelo Ano de Ingresso", tools = [TOOLS])

# %% [markdown]
# ## Análise 5 - Notas Enem x Ano de Ingresso.
#
# Nesta seção utilizamos os dados das notas do Enem dos alunos em relação ao ano de ingresso.
#
# No primeiro Gráfico, podemos ver que apesar de alguns poucos Outliers para cima ou para baixo da distruibuição, a média geral dos alunos se manteve próxima aos 620 pontos em todos oos anos.
#
# No segundo Gráfico para as notas da redação, com uma distruibuição um pouco menos concentrada do que as notas gerais, ainda assim temos cerca 50% dos alunos com notas em torno de 600 à bem próximo dos 800, que no geral chegam a ser boas notas.
#
# No terceiro Gráfico............

# %%
row1 = [Notas_Enem2014,Notas_Enem2015]

# Create a list containing plots p3 and p4: row2
row2 = [Notas_Enem2016]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b8061020-088d-4da1-a612-2e746a261f98">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="427c3aaf-10cb-44df-a2f2-66dfcbf3237e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("427c3aaf-10cb-44df-a2f2-66dfcbf3237e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("427c3aaf-10cb-44df-a2f2-66dfcbf3237e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '427c3aaf-10cb-44df-a2f2-66dfcbf3237e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"
# %% [markdown]
# ### Usando plotly para gerar gráficos pizza de acordo com os dados fornecidos.

# %%
# Filter by status (ATIVO, CANCELADO and TRANCADO)
a = data
a = a.loc[a['status'] != 'FORMADO']
a = a.loc[a['status'] != 'FORMANDO']
a = a.loc[a['status'] != 'CONCLUIDO']
a = a.loc[a['status'] != 'FORMADO']
a = pd.DataFrame(a.groupby('status')['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2014
a14 = data.loc[data['ano_ingresso'] == 2014]
a14 = a14.loc[a14['status'] != 'FORMADO']
a14 = a14.loc[a14['status'] != 'FORMANDO']
a14 = a14.loc[a14['status'] != 'CONCLUIDO']
a14 = a14.loc[a14['status'] != 'FORMADO']
a14 = pd.DataFrame(a14.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2015
a15 = data.loc[data['ano_ingresso'] == 2015]
a15 = a15.loc[a15['status'] != 'FORMADO']
a15 = a15.loc[a15['status'] != 'FORMANDO']
a15 = a15.loc[a15['status'] != 'CONCLUIDO']
a15 = a15.loc[a15['status'] != 'FORMADO']
a15 = pd.DataFrame(a15.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2016
a16 = data.loc[data['ano_ingresso'] == 2016]
a16 = a16.loc[a16['status'] != 'FORMADO']
a16 = a16.loc[a16['status'] != 'FORMANDO']
a16 = a16.loc[a16['status'] != 'CONCLUIDO']
a16 = a16.loc[a16['status'] != 'FORMADO']
a16 = pd.DataFrame(a16.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# %%
# Load data from dataframes into figure object
fig = {
    'data': [
        {
            'labels': a16['status'],
            'values': a16['a_ID'],
            'type': 'pie',
            'name': '2016',
            'domain': {'x': [0, .48], 'y': [0, .49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a['status'],
            'values': a['a_ID'],
            'type': 'pie',
            'name': '2014-2016',
            'domain': {'x': [.52, 1], 'y': [0, .49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a14['status'],
            'values': a14['a_ID'],
            'type': 'pie',
            'name': '2014',
            'domain': {'x': [0, .48], 'y': [.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a15['status'],
            'values': a15['a_ID'],
            'type': 'pie',
            'name':'2015',
            'domain': {'x': [.52, 1], 'y': [.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Distribuição de alunos por ano de ingresso e situação',
        'annotations':[
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2014',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2015',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2016',
                    'x': 0.21,
                    'y': 0.21
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': '14 - 16',
                    'x': 0.79,
                    'y': 0.21
                }
        ]
    }
}

# %% [markdown]
# ## Análise 6 - Ano de Ingresso x Status.
#
# Para verificar o andamento anual do curso, decidimos analisar a situação dos alunos (status) a cada ano e também ao total dos 3 anos.
#
# Nesta seção utilizamos os dados dos status dos alunos em relação ao seus anos de ingresso.

# %%
# Plot pie charts
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~rubemkalebe/12.embed" height="525px" width="100%"></iframe>

# %%
d = data
d['count'] = 0

# Filter by qtd_matriculas and disciplina 0
d0 = d[d['disciplina_ID']==0]
d0 = pd.DataFrame(d0.groupby('a_ID')['count'].count()).reset_index()
d0 = d0.rename(columns = {'count':'qtd_matriculas'})
d0['count'] = 0
d0 = pd.DataFrame(d0.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 1
d1 = d[d['disciplina_ID']==1]
d1 = pd.DataFrame(d1.groupby('a_ID')['count'].count()).reset_index()
d1 = d1.rename(columns = {'count':'qtd_matriculas'})
d1['count'] = 0
d1 = pd.DataFrame(d1.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 2
d2 = d[d['disciplina_ID']==2]
d2 = pd.DataFrame(d2.groupby('a_ID')['count'].count()).reset_index()
d2 = d2.rename(columns = {'count':'qtd_matriculas'})
d2['count'] = 0
d2 = pd.DataFrame(d2.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 3
d3 = d[d['disciplina_ID']==3]
d3 = pd.DataFrame(d3.groupby('a_ID')['count'].count()).reset_index()
d3 = d3.rename(columns = {'count':'qtd_matriculas'})
d3['count'] = 0
d3 = pd.DataFrame(d3.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 4
d4 = d[d['disciplina_ID']==4]
d4 = pd.DataFrame(d4.groupby('a_ID')['count'].count()).reset_index()
d4 = d4.rename(columns = {'count':'qtd_matriculas'})
d4['count'] = 0
d4 = pd.DataFrame(d4.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 5
d5 = d[d['disciplina_ID']==5]
d5 = pd.DataFrame(d5.groupby('a_ID')['count'].count()).reset_index()
d5 = d5.rename(columns = {'count':'qtd_matriculas'})
d5['count'] = 0
d5 = pd.DataFrame(d5.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 6
d6 = d[d['disciplina_ID']==6]
d6 = pd.DataFrame(d6.groupby('a_ID')['count'].count()).reset_index()
d6 = d6.rename(columns = {'count':'qtd_matriculas'})
d6['count'] = 0
d6 = pd.DataFrame(d6.groupby('qtd_matriculas')['count'].count()).reset_index()

# %%
# Load data from dataframes into figure object
fig1 = {
    'data': [
        {
            'labels': d2['qtd_matriculas'],
            'values': d2['count'],
            'type': 'pie',
            'name': 'Disciplina 2',
            'domain': {'x': [0, .48], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d3['qtd_matriculas'],
            'values': d3['count'],
            'type': 'pie',
            'name': 'Disciplina 3',
            'domain': {'x': [.52, 1], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d0['qtd_matriculas'],
            'values': d0['count'],
            'type': 'pie',
            'name': 'Disciplina 0',
            'domain': {'x': [0, .48], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d1['qtd_matriculas'],
            'values': d1['count'],
            'type': 'pie',
            'name':'Disciplina 1',
            'domain': {'x': [.52, 1], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Disciplina pela Quantidade de vezes que alunos se matricularam (Disciplina 0 à 3)',
        'annotations':[
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_0',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_1',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_2',
                    'x': 0.21,
                    'y': 0.21
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_3',
                    'x': 0.79,
                    'y': 0.21
                }
        ]
    }
}

# %% [markdown]
# ## Análise 7 - Disciplina x Quantida de vezes que alunos se matricularam
#
# De acordo com o regulamento da UFRN, é previsto o cancelamento do programa se houver desempenho acadêmico insuficiente por parte do aluno. Ainda de acordo com o regulamento, **Seção III (15.16.3. DO DESEMPENHO ACADÊMICO INSUFICIENTE), Art. 327 - I**:
#
# ***"Caracteriza-se o desempenho acadêmico insuficiente quando, em um período letivo regular no qual o programa não está suspenso, ocorre uma ou mais das seguintes situações: Insucesso (trancamento e/ou reprovação) pela quarta vez ou mais, consecutiva ou não, em um mesmo componente curricular obrigatório ou seus equivalentes;"***
#
#
# Com o objetivo de verificar o andamento de cada disciplina e assim analisar quais têm causado mais dificuldades aos alunos, inclusive abrindo possibilidades de cancelamento de seus programas, levantamos os dados que mostram a quantidade de vezes que os alunos se matricularam nas disciplinas no decorrer do tempo (intervalo de 2014 à 2016).

# %%
# Plot pie charts
py.iplot(fig1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~rubemkalebe/14.embed" height="525px" width="100%"></iframe>

# %%
fig2 = {
    'data': [
        {
            'labels': d6['qtd_matriculas'],
            'values': d6['count'],
            'type': 'pie',
            'name': 'Disciplina 6',
            'domain': {'x': [0, .48], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d4['qtd_matriculas'],
            'values': d4['count'],
            'type': 'pie',
            'name': 'Disciplina 4',
            'domain': {'x': [0, .48], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d5['qtd_matriculas'],
            'values': d5['count'],
            'type': 'pie',
            'name':'Disciplina 5',
            'domain': {'x': [.52, 1], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Disciplina pela Quantidade de vezes que alunos se matricularam (Disciplina 4 à 6)',
        'annotations':[
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_4',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_5',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_6',
                    'x': 0.21,
                    'y': 0.21
                }
        ]
    }
}

# %%
py.iplot(fig2)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~rubemkalebe/16.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Análise 8 - Evolução temporal das disciplinas
#
# Nesta seção utilizamos a quantidade de aprovados e reprovados, além do total de matriculados em cada disciplina, para mostrar o desenvolvimento de cada disciplina no decorrer dos anos em que foram ofertadas.
#
# A análise do quanto uma disciplina vem aprovando, ou reprovando, é útil para encontrar disciplinas nas quais os estudantes apresentam dificuldades ou ainda, disciplinas que eventualmente têm se tornado mais complicada para eles. Um gráfico de linhas é ideal para apresentar essa evolução no decorrer do tempo.
#
# À primeira vista, percebe-se que os alunos apresentam mais dificuldades nas disciplinas 3, 5 e 6. A disciplina 0 também apresenta-se de complexidade razoável e a disciplina 2, a qual antes não poderia ser considerada de grande complexidade, passou a reprovar a maior parte dos seus alunos.
#
# As disciplinas 1 e 4 aparentam serem melhor aproveitadas pelos alunos e a tendência de crescimento na quantidade de matriculados mostra que essas disciplinas não sofreram mudanças que alterassem a tendência de aprovação.
#
# A disciplina 6 apresenta uma tendência preocupante de "reprovar mais do que aprovar". Com o passar dos anos, a quantidade de aprovados praticamente se manteve constante, enquanto que a quantidade de reprovados cresceu linearmente.

# %%
df1 = data[data['ano_disciplina'] != 2017]
df1['count_reprovados'] = 0
df1['count_aprovados'] = 0
df1['count_total'] = 0
df1['count_rep_periodo'] = 0

reprovados = df1[df1["status.disciplina"] == "Reprovado"]
aprovados = df1[df1["status.disciplina"] == "Aprovado"]

reprovados_count = pd.DataFrame(reprovados.groupby(['disciplina_ID','ano_disciplina'])['count_reprovados'].count()).reset_index()
aprovados_count = pd.DataFrame(aprovados.groupby(['disciplina_ID','ano_disciplina'])['count_aprovados'].count()).reset_index()
total_count = pd.DataFrame(df1.groupby(['disciplina_ID','ano_disciplina'])['count_total'].count()).reset_index()
rep_periodo_count = pd.DataFrame(reprovados.groupby(['ano_disciplina', 'periodo_disciplina'])['count_rep_periodo'].count()).reset_index()
# Out:
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool

def getSource(disc):
    return ColumnDataSource(data = {
        'anos': [str(x) for x in reprovados_count[reprovados_count["disciplina_ID"] == disc]['ano_disciplina']],
        'reprovados': reprovados_count[reprovados_count["disciplina_ID"] == disc]['count_reprovados'],
        'aprovados' : aprovados_count[aprovados_count["disciplina_ID"] == disc]['count_aprovados'],
        'total' : total_count[total_count["disciplina_ID"] == disc]['count_total']
    }
)

def getFigure(disc):
    source = getSource(disc)
    p = figure(plot_width = 600, plot_height = 400, x_axis_label = 'Anos', y_axis_label = 'Número de alunos',
               x_range = source.data['anos'], title = 'Aprovados/Reprovados na Disciplina ' + str(disc))
    p.line(x = 'anos', y = 'reprovados', color = "red", line_width = 3, source = source, legend='Reprovados')
    p.circle(x = 'anos', y = 'reprovados', fill_color = "white", size = 7, source = source)
    p.line(x = 'anos', y = 'aprovados', color = "green",line_width = 3, source = source, legend='Aprovados')
    p.circle(x = 'anos', y = 'aprovados', fill_color = "white", size = 7, source=source)
    p.line(x = 'anos', y = 'total', color = "blue", line_width = 3, source = source, legend='Total')
    p.circle(x = 'anos', y = 'total', fill_color = "white", size = 7, source = source)
    p.legend.location = "top_left"
    return p

tab1 = Panel(child = getFigure(0), title = "Disciplina 0")
tab2 = Panel(child = getFigure(1), title = "Disciplina 1")
tab3 = Panel(child = getFigure(2), title = "Disciplina 2")
tab4 = Panel(child = getFigure(3), title = "Disciplina 3")
tab5 = Panel(child = getFigure(4), title = "Disciplina 4")
tab6 = Panel(child = getFigure(5), title = "Disciplina 5")
tab7 = Panel(child = getFigure(6), title = "Disciplina 6")
tabs = Tabs(tabs = [tab1, tab2, tab3, tab4, tab5, tab6, tab7])


output_notebook()
show(tabs)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d8d4092b-d713-4184-bcee-4e3200eeceae">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e023117a-70f1-4bd0-9506-ebc53cd34967"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e023117a-70f1-4bd0-9506-ebc53cd34967").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e023117a-70f1-4bd0-9506-ebc53cd34967");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e023117a-70f1-4bd0-9506-ebc53cd34967' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b7c3b7ef-1d2e-44af-a243-928ba7b70284":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["anos","reprovados","aprovados","total"],"data":{"anos":["2014","2015","2016"],"aprovados":[66,116,78],"reprovados":[105,165,253],"total":[171,281,331]}},"id":"081d2606-d73f-4763-b863-cac70b5c5306","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"890d20c3-f208-4077-9a84-390339ecdbb5","type":"CategoricalAxis"}],"left":[{"id":"2c8dff89-d533-4ad8-9881-704127049aeb","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"890d20c3-f208-4077-9a84-390339ecdbb5","type":"CategoricalAxis"},{"id":"89993583-47a2-4f6a-8f43-995631295036","type":"Grid"},{"id":"2c8dff89-d533-4ad8-9881-704127049aeb","type":"LinearAxis"},{"id":"68c92287-f6a0-4331-9602-b6f24abe17c1","type":"Grid"},{"id":"da3e9d76-15a5-40ff-8480-5cd4bdd2a639","type":"BoxAnnotation"},{"id":"9f5008a8-bb39-486c-b30d-349d8c44b1a7","type":"Legend"},{"id":"4c32fe60-0105-440e-9fd0-9c4767dc7a48","type":"GlyphRenderer"},{"id":"a72cae45-e6b9-40fe-8554-5360718a7635","
type":"CategoricalTicker"},{"attributes":{"plot":{"id":"0b0beec0-d52b-4c42-a92d-30798beaecf7","subtype":"Figure","type":"Plot"},"ticker":{"id":"ddf12cbb-e7c3-4e95-ba0f-39ee85274ecc","type":"CategoricalTicker"}},"id":"89993583-47a2-4f6a-8f43-995631295036","type":"Grid"},{"attributes":{"axis_label":"N\u00famero de alunos","formatter":{"id":"504f5ec4-85b8-4f07-af44-cea0797d47a5","type":"BasicTickFormatter"},"plot":{"id":"0b0beec0-d52b-4c42-a92d-30798beaecf7","subtype":"Figure","type":"Plot"},"ticker":{"id":"1147767c-765f-4e5d-ac9d-1aaa11a393f8","type":"BasicTic ...

# %% [markdown]
# ## Análise 9 - Evolução temporal dos períodos
#
# Nesta seção utilizamos a quantidade de reprovados para mostrar o desenvolvimento dos períodos no decorrer dos anos para determinar se os períodos estão equilibrados.
#
# Entre 2014 e 2015 os períodos seguiam a mesma tendência e o 2º Período se apresentava como mais desafiador aos alunos. Todavia, em 2016 o 1º Período teve um grande salto no número de reprovados (reprovou mais de 400 alunos a mais do que no ano anterior) e passou a ser, momentaneamente, o semestre mais desafiador. Essa tendência de um ano de 2016 mais complicado para os alunos já foi notada em análises anteriores que apresentaram altos níveis de reprovação nas disciplinas 2, 3, 5 e 6.
#
# O 2º Período manteve sua tendência.

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool

source = ColumnDataSource(data = {
        'anos': [str(x) for x in rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 1]['ano_disciplina']],
        'reprovados1': rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 1]['count_rep_periodo']
    }
)

source2 = ColumnDataSource(data = {
        'anos': [str(x) for x in rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 2]['ano_disciplina']],
        'reprovados2' : rep_periodo_count[rep_periodo_count["periodo_disciplina"] == 2]['count_rep_periodo']
    }
)

p = figure(plot_width = 600, plot_height = 400, x_axis_label = 'Anos', y_axis_label = 'Número de alunos',
           x_range = source.data['anos'], title = 'Reprovados por período')
p.line(x = 'anos', y = 'reprovados1', color = "purple", line_width = 3, source = source, legend='1º Período')
p.circle(x = 'anos', y = 'reprovados1', fill_color = "white", size = 7, source = source)
p.line(x = 'anos', y = 'reprovados2', color = "orange",line_width = 3, source = source2, legend='2º Período')
p.circle(x = 'anos', y = 'reprovados2', fill_color = "white", size = 7, source=source2)
p.legend.location = "top_left"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fb7c7517-fcf8-46fb-8e46-41d958045005">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0a9c61cf-3c2b-40b4-92ed-67aee3fb91c1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0a9c61cf-3c2b-40b4-92ed-67aee3fb91c1").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a9c61cf-3c2b-40b4-92ed-67aee3fb91c1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a9c61cf-3c2b-40b4-92ed-67aee3fb91c1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b7e9c14d-ddab-483e-ba45-2cd35f78b57f":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["anos","reprovados2"],"data":{"anos":["2014","2015","2016"],"reprovados2":[246,358,455]}},"id":"596941f2-d902-4558-b802-1fcc909c8d2b","type":"ColumnDataSource"},{"attributes":{},"id":"7f044b84-551f-429b-a00e-f47f86c982f7","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"anos"},"y":{"field":"reprovados1"}},"id":"1597afb9-a2de-4368-816b-7ec59534ece5","type":"Circle"},{"attributes":{"data_source":{"id":"596941f2-d902-4558-b802-1fcc909c8d2b","type":"ColumnDataSource"},"glyph":{"id":"50288a93-d3ca-4e92-8fbd-41686a2b58e0","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"04d84fbe-3dcf-461d-94f0-f8143222aa8b","type":"Line"},"selection_glyph":null},"id":"57c5727f-7a6d-478f-bb33-3b90f3c16ec7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"
type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"a22ad416-8e47-4335-a315-da8d14586b9b","type":"Circle"} ...

# %% [markdown]
# ## Análise 10 - Evolução temporal dos alunos que cancelaram ou trancaram
#
# Nesta seção analisamos a quantidade de alunos que cancelaram ou trancaram no decorrer dos anos, para tentar fazer um paralelo com análises anteriores, principalmente as que envolvem número de reprovações.
#
# Percebe-se que o número de alunos que cancelaram ou trancaram cresceu além da tendência dos anos anteriores. Isso deve ter sido incentivado pelo baixo desempenho dos alunos naquele ano.

# %%
df2 = data[data['ano_disciplina'] != 2017]
df2['count_cancelado'] = 0
df2['count_trancado'] = 0

cancelado = df2[df2["status"] == "CANCELADO"]
trancado = df2[df2["status"] == "TRANCADO"]

cancelado_count = pd.DataFrame(cancelado.groupby(['a_ID','ano_disciplina'])['count_cancelado'].count()).reset_index()
trancado_count = pd.DataFrame(trancado.groupby(['a_ID','ano_disciplina'])['count_trancado'].count()).reset_index()

cancelado_dic = {}
trancado_dic = {}

for ind in set(cancelado_count['a_ID']):
    a = cancelado_count[cancelado_count['a_ID'] == ind]['ano_disciplina'].tail(1)
    if str(int(a)) in cancelado_dic:
        cancelado_dic[str(int(a))] += 1
    else:
        cancelado_dic[str(int(a))] = 1
        
for ind in set(trancado_count['a_ID']):
    a = trancado_count[trancado_count['a_ID'] == ind]['ano_disciplina'].tail(1)
    if str(int(a)) in trancado_dic:
        trancado_dic[str(int(a))] += 1
    else:
        trancado_dic[str(int(a))] = 1
# Out:
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubemkalebe/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.palettes import Spectral6

source1 = ColumnDataSource(data = {
        'anos': [str(x) for x in sorted(cancelado_dic.keys())],
        'cancelado': [cancelado_dic[x] for x in sorted(cancelado_dic.keys())]
    }
)

source2 = ColumnDataSource(data = {
        'anos': [str(x) for x in sorted(trancado_dic.keys())],
        'trancado': [trancado_dic[x] for x in sorted(trancado_dic.keys())]
    }
)


p = figure(plot_width = 600, plot_height = 400, x_axis_label = 'Anos', y_axis_label = 'Número de alunos',
           x_range = source.data['anos'], title = 'Situação dos alunos')

p.line(x = 'anos', y = 'cancelado', color = Spectral6[0], line_width = 3, source = source1, legend = 'Cancelado')
p.circle(x = 'anos', y = 'cancelado', fill_color = "white", size = 7, source = source1)

p.line(x = 'anos', y = 'trancado', color = Spectral6[1], line_width = 3, source = source2, legend='Trancado')
p.circle(x = 'anos', y = 'trancado', fill_color = "white", size = 7, source=source2)
p.legend.location = "top_left"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6d96634e-5e14-4f3a-9f18-41302541e8ca">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="700d5950-6d42-463b-a4f7-6888a2058159"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("700d5950-6d42-463b-a4f7-6888a2058159").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("700d5950-6d42-463b-a4f7-6888a2058159");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '700d5950-6d42-463b-a4f7-6888a2058159' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2e517f77-5187-4257-8c33-965e1156751f":{"roots":{"references":[{"attributes":{"data_source":{"id":"0242abab-3bff-49c6-97ee-1c75fed951cf","type":"ColumnDataSource"},"glyph":{"id":"4d3a0be6-d24b-4f43-9aca-2fcba32317ac","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"