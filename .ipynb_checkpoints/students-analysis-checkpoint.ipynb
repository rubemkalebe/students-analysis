# %% [markdown]
# #### Load and prepare data:

# %%
# Import pandas, plotly and bokeh.
import pandas as pd
import plotly.plotly as py
from bokeh.plotting import figure,ColumnDataSource
from bokeh.io import output_notebook, show
from bokeh.models import HoverTool, NumeralTickFormatter
from bokeh.layouts import gridplot
from bokeh.charts import Histogram, Bar, output_file, Scatter,BoxPlot, output_file, show


# Assign spreadsheet filename: file
file = 'imd_student_blind.xlsx'

# Load spreadsheet: xl
xl = pd.ExcelFile(file)

# Print sheet names
print(xl.sheet_names)

# Load the sheet into a DataFrame by index: data
data = xl.parse(0)
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,wheel_zoom, pan'
# Out:
# ['Sheet1']

# %%
# Print the head of the DataFrame data
data.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota
# 0          0           640      618.0
# 1          0           640      618.0
# 2          0           660      615.0
# 3          0           560      600.0
# 4          0           760      673.0

# %%
source = ColumnDataSource(data)
data['count'] = 0
data.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota  count
# 0          0           640      618.0      0
# 1          0           640      618.0      0
# 2          0           660      615.0      0
# 3          0           560      600.0      0
# 4          0           760      673.0      0

# %%
d = data[data["status.disciplina"] == "Reprovado"]
df1 = pd.DataFrame(d.groupby(['disciplina_ID','ano_disciplina'])['count'].count()).reset_index()
df1.head(10)
# Out:
#    disciplina_ID  ano_disciplina  count
# 0              0            2014     73
# 1              0            2015    105
# 2              0            2016    143
# 3              1            2014     35
# 4              1            2015     29
# 5              1            2016     42
# 6              1            2017      3
# 7              2            2014     47
# 8              2            2015     47
# 9              2            2016    229

# %%
dataYear2014_ID = df1[df1["ano_disciplina"] == 2014]["disciplina_ID"]
dataYear2014_count = df1[df1["ano_disciplina"] == 2014]["count"]


dataYear2015_ID = df1[df1["ano_disciplina"] == 2015]["disciplina_ID"]
dataYear2015_count = df1[df1["ano_disciplina"] == 2015]["count"]

dataYear2016_ID = df1[df1["ano_disciplina"] == 2016]["disciplina_ID"]
dataYear2016_count = df1[df1["ano_disciplina"] == 2016]["count"]

dataYear2016_count.head(100)
# Out:
# 2     143
# 5      42
# 9     229
# 12    178
# 15     58
# 19    253
# 22    179
# Name: count, dtype: int64

# %%
#source = ColumnDataSource(df1)

Reprovados_Disc2014 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2014', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])
Reprovados_Disc2015 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2015', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])
Reprovados_Disc2016 = figure(title='Scatter Nº de reprovados pelas disciplinas, Ano de 2016', x_axis_label='Disciplina', y_axis_label='Nº Reprovados',tools=[TOOLS])


Reprovados_Disc2014.circle(dataYear2014_ID,dataYear2014_count,size=10,color = 'green')
Reprovados_Disc2015.circle(dataYear2015_ID,dataYear2015_count,size=10,color = 'navy')
Reprovados_Disc2016.circle(dataYear2016_ID,dataYear2016_count,size=10,color = 'red')
# Out:
# GlyphRenderer(id='41085216-0513-4c46-90c9-830948797d26', ...)

# %% [markdown]
# ## Gráfico 1 - Número de Reprovados x Disciplina em cada ano.
#
# Nesta seção utilizamos os dados do número de reprovados em cada uma das disciplinas disponíveis, pelos anos em que elas foram ofertadas.
#
# "Há um sistema pré-estabelecido ao qual o aluno precisa se adaptar, se inserir, como um ritual de passagem. Quem não for capaz de cumprir etapas estabelecidas pela coordenação da disciplina, provavelmente, será reprovado.”
#
# #### Fabiana Colombo Garzella,
# **A disciplina de Cálculo I: a análise das relações entre as práticas pedagógicas do professor e seus impactos nos alunos**
#
# O Número de reprovados em algumas disciplinas do Curso do Bacharelado em Tecnologia da Informação, tem crescido rapidamente e é algo que deve ser revisado. Pensando nisso resolvemos analisar o número de reprovados em cada uma das disciplinas disponíveis, pelos anos em que elas foram ofertadas.
#
# Como visto, algumas disciplinas, a cada ano, tem seu número de reprovações aumentando. Além de outros possíveis fatores, a forma como a disciplina está sendo ofertada, a relação do aluno com os professores ou a quantidade de alunos em uma única turma, deve ser revisada pela coordenação ou setor pedagógico.
# Nos gráficos, podemos destacar a disciplina 5, que a cada ano aumenta o número de reprovados, chegando a 2016 com mais de 250 reprovações naquele ano. A disciplina 2, apesar de ter mantido esse valor de 2014 para 2015 com cerca de 50, teve em torno de 230 reprovações em 2016. A disciplina 3 também teve um aumento considerável, já que em 2014 o valor era de aproximadamente 50 para em torno de 180 em 2016.

# %%
row1 = [Reprovados_Disc2014,Reprovados_Disc2015]

# Create a list containing plots p3 and p4: row2
row2 = [Reprovados_Disc2016]

layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()

# Display the plot
show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="32dd5d8a-5a71-4425-a820-a81cc80067f9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5b342c99-4ee4-4a73-a312-7b4b2325e895"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5b342c99-4ee4-4a73-a312-7b4b2325e895").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b342c99-4ee4-4a73-a312-7b4b2325e895");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b342c99-4ee4-4a73-a312-7b4b2325e895' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d4fb6c59-fd37-4500-946b-06ede3f42289":{"roots":{"references":[{"attributes":{"plot":{"id":"77ba7077-2c8e-4f72-9e07-30c90d95025a","subtype":"Figure","type":"Plot"},"ticker":{"id":"a36f2aac-88bc-490f-8ace-375d1b469336","type":"BasicTicker"}},"id":"0d011dad-f4f8-4cb7-a034-d4883532cce8","type":"Grid"},{"attributes":{"plot":{"id":"77ba7077-2c8e-4f72-9e07-30c90d95025a","subtype":"Figure","type":"Plot"}},"id":"6e4128c7-7ef8-4799-abcc-a5460d972bba","type":"PanTool"},{"attributes":{"callback":null,"overlay":{"id":"dfba6fd8-dd0e-4fae-bb08-5fc4db63d09c","type":"BoxAnnotation"},"plot":{"id":"77ba7077-2c8e-4f72-9e07-30c90d95025a","subtype":"Figure","type":"Plot"},"renderers":[{"id":"5ea1a569-e08b-478f-8a77-4659784a8f53","type":"GlyphRenderer"}]},"id":"0b0ac737-8abd-452b-8f39-fff2561580d0","type":"BoxSelectTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6],"y":[105,29,47,100,16,165,91]}},"id":"48fc2055-e8ec-4270-a814-1622d674708b","type":"ColumnDataSource"},{"attributes":{"axis_label":"Disciplina","formatter":{"id":"c52e5236-3622-4256-bbf0-043fb6991b71","type":"BasicTickFormatter"},"plot":{"id":"91a49ae1-8763-4293-a633-1a38ee604a49","subtype":"Figure","type":"Plot"},"ticker":{"id":"48ef025f-93fa-4ffd-a7dd-3aeadd314748","type":"BasicTicker"}},"id":"5c5723f9-24e8-4e61-a2e5-08873cc9eac7","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dfba6fd8-dd0e-4fae-bb08-5fc4db63d09c","type":"BoxAnnotation"},{"attributes":{},"id":"d813d74d-ce76-44fa-98c8-f022daf5ecd6","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Scatter N\u00ba de reprovados pelas disciplinas, Ano de 2016"},"id":"270c0058-fdfc-4c6d-b347-45125c1ec65f","type":"Title"},{"attributes":{},"id":"a36f2aac-88bc-490f-8ace-375d1b469336","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6],"y":[73,35,47,56,14,105,33]}},"id":"eb4f3f40-ddee-4638-b3fd-61afaac90794","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"77ba7077-2c8e-4f72-9e07-30c90d95025a","subtype":"Figure","type":"Plot"}},"id":"07837562-de9a-44b9-a0e5-23faeaefe09d","type":"CrosshairTool"},{"attributes":{"plot":{"id":"91a49ae1-8763-4293-a633-1a38ee604a49","subtype":"Figure","type":"Plot"},"ticker":{"id":"48ef025f-93fa-4ffd-a7dd-3aeadd314748","type":"BasicTicker"}},"id":"f35c9989-3e6d-483a-a6f5-a2cc4afd38f7","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a46e2460-2659-48c1-92b6-647d83d7451e","type":"BoxZoomTool"},{"id":"65d0bafc-9419-4fcb-9868-ab0be9ea7b9b","type":"BoxSelectTool"},{"id":"6c6b61e2-6b5e-4dd4-94fb-4fc1d6fe2755","type":"CrosshairTool"},{"id":"8021821f-c172-4454-9a14-b1a8fcc4ca86","type":"ResizeTool"},{"id":"0514acb2-a890-4361-9d60-735d269dc306","type":"ResetTool"},{"id":"ff8a5bbf-7378-437e-992b-b20dcc76c7a7","type":"WheelZoomTool"},{"id":"e4c7074f-7572-40dc-81a0-37e882e6e942","type":"PanTool"}]},"id":"db81bf7e-3be7-4438-a669-2c3d08e1a12d","type":"Toolbar"},{"attributes":{},"id":"48ef025f-93fa-4ffd-a7dd-3aeadd314748","type":"BasicTicker"},{"attributes":{"plot":{"id":"77ba7077-2c8e-4f72-9e07-30c90d95025a","subtype":"Figure","type":"Plot"}},"id":"4af8d9f9-29ca-44a9-95ad-6a5bd9725300","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7dec022b-ac62-4975-ab63-456a1b364aa7","type":"BoxZoomTool"},{"id":"46b21e55-a0ae-4890-9a7d-9a657b950cbf","type":"BoxSelectTool"},{"id":"cecf6882-9475-4879-a830-fec9f9c5219e","type":"CrosshairTool"},{"id":"2fd546da-0931-4e04-8724-1498fbb1a71a","type":"ResizeTool"},{"id":"29062d6b-2552-45b1-b8be-f94cbd66feea","type":"ResetTool"},{"id":"9a59a4c7-9fb7- ...

# %% [markdown]
# ## Gráfico 2 - Número de Reprovados x Disciplina em todos os anos.
#
# Nesta seção utilizamos os dados do número de reprovados em cada uma das disciplinas disponíveis, em todos os anos.
#
# "Entre os fatores determinantes para esse quadro, a pesquisa relaciona o grande número de alunos por turma, impedindo que necessidades particulares de determinados grupos de alunos sejam atendidas. No caso do semestre observado, existiam 30 turmas da disciplina, com média de 40 alunos cada. Três turmas eram agrupadas em uma sala de aula, totalizando aproximadamente 150 alunos. No conjunto, havia 10 salas composta por três turmas, cada uma com um professor responsável."
#
# #### Fabiana Colombo Garzella,
# **A disciplina de Cálculo I: a análise das relações entre as práticas pedagógicas do professor e seus impactos nos alunos**
#
# Como podemos ver abaixo, o crescente número de reprovados também pode ser influenciado pela necessidade de compensar alunos reprovados em semestres anteriores, aumentando a quantidade de de alunos por turma e consequentemente, a necessidade de abrir mais turmas para as diciplinas.
# No gráfico, podemos ver a disciplina 5 com um total de mais de 500 reprovados somandos todas as suas ofertas desde o ano de 2014 até o ano de 2016. Enquanto outras disciplinas, não menos importantes tem um valor considerevável com algo em torno de 320 reprovações. As disciplinas 1 e 4 possuem o menor número, com cerca de 120 e 160 respectivamente.

# %%
#from bokeh.plotting import figure, output_file, show

#mypalette = Spectral11[0:10]
#source = ColumnDataSource(df1)

#df1.plot(kind = 'line')
Bar_Reprovados = Bar(df1, 'disciplina_ID', values='count',color = 'disciplina_ID', xlabel="Disciplina",  
         ylabel = "Nº de Reprovados", title="Disciplinas pelo Nº de Reprovados", 
         legend = 'top_right', width = 10,tools=[TOOLS])

output_notebook()
show(Bar_Reprovados)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c4c52dd3-9959-461d-82c5-749fda31bc30">Loading BokehJS ...</span>
#     </div>
# C:\Users\Eduardo\Anaconda3\lib\site-packages\bokeh\core\json_encoder.py:73: FutureWarning:
#
# pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7e447623-a756-42dd-8760-04e087929a06"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7e447623-a756-42dd-8760-04e087929a06").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7e447623-a756-42dd-8760-04e087929a06");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7e447623-a756-42dd-8760-04e087929a06' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"848cd0d9-fa99-4d98-8e72-bf20fa03e6fb":{"roots":{"references":[{"attributes":{"callback":null,"end":549.15},"id":"dc3b4839-0d25-4c39-86ee-b7fa5bde831b","type":"Range1d"},{"attributes":{"label":{"value":"6"},"renderers":[{"id":"122b88a1-2a32-4b7b-aa57-2f24a611241b","type":"GlyphRenderer"}]},"id":"d4198977-1d1d-4382-9747-b41e08c5511e","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":6}],"color":["#f22c40"],"disciplina_ID":[6],"fill_alpha":[0.8],"height":[303.0],"label":[{"disciplina_ID":6}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["6"],"y":[151.5]}},"id":"02c0b4fd-2649-45ce-bff5-52dc3a407df3","type":"ColumnDataSource"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"d752a606-ac4d-49c5-99d9-dc6dc051b79d","type":"GlyphRenderer"}]},"id":"98a6f7f0-5159-479e-a891-71a6ad4cfaa6","type":"LegendItem"},{"attributes":{"below":[{"id":"5aa7c5e8-ec01-4ed8-8075-e1d3a78a8b89","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"f74b527a-4d57-4c85-b990-7d5aea0c9c65","type":"LinearAxis"}],"renderers":[{"id":"d75c87a4-a5e3-472f-81ca-925726e37f03","type":"BoxAnnotation"},{"id":"45c00c2f-b45e-4f0a-a385-e641bb95d3ed","type":"BoxAnnotation"},{"id":"d752a606-ac4d-49c5-99d9-dc6dc051b79d","type":"GlyphRenderer"},{"id":"74442092-761a-4fe6-a073-27b531d37de7","type":"GlyphRenderer"},{"id":"b2359037-39b3-4509-95f2-e5e51cbdf869","type":"GlyphRenderer"},{"id":"b8a04783-cd8b-477a-b6c2-acd952c93d5f","type":"GlyphRenderer"},{"id":"2d5e644a-67c7-4222-bbf4-28dda1571efd","type":"GlyphRenderer"},{"id":"5d399a2b-2b70-4e51-91b9-d1e11281060a","type":"GlyphRenderer"},{"id":"122b88a1-2a32-4b7b-aa57-2f24a611241b","type":"GlyphRenderer"},{"id":"625610cc-8f85-40bb-aacd-7f9c5532d8d1","type":"Legend"},{"id":"5aa7c5e8-ec01-4ed8-8075-e1d3a78a8b89","type":"CategoricalAxis"},{"id":"f74b527a-4d57-4c85-b990-7d5aea0c9c65","type":"LinearAxis"},{"id":"1981d90a-b870-43a3-b358-b98ca39cca53","type":"Grid"}],"title":{"id":"3c159fc3-04d4-44e4-bcea-7e569186642a","type":"Title"},"tool_events":{"id":"fe6f0ac0-15dc-43e7-b8e7-04535de185c6","type":"ToolEvents"},"toolbar":{"id":"ee0f0a8f-a53e-4b72-8462-778bd9b564fa","type":"Toolbar"},"width":10,"x_mapper_type":"auto","x_range":{"id":"0ffa8683-3189-48da-a6f7-1e45d21113dd","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"dc3b4839-0d25-4c39-86ee-b7fa5bde831b","type":"Range1d"}},"id":"7a0338fb-55b9-4e8e-8006-970c4d78472f","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"44524318-5113-4ad5-87a9-8a0aeae2491d","type":"ColumnDataSource"},"glyph":{"id":"bae9c277-ac9b-4346-9cc3-476ecf80d1df","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2d5e644a-67c7-4222-bbf4-28dda1571efd","type":"GlyphRenderer"},{"attributes":{},"id":"fe6f0ac0-15dc-43e7-b8e7-04535de185c6","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5d92c670-4aba-4b52-9671-62141a93f67f","type":"BoxZoomTool"},{"id":"a5dda40b-7209-4459-8791-fded6118d145","type":"BoxSelectTool"},{"id":"f954e585-0ab0-4b5b-9525-2655bd15f7b0","type":"CrosshairTool"},{"id":"07f9097e-ce59-4d83-be1e-efbac3a7dc57","type":"ResizeTool"},{"id":"852447b1-3eb0-4952-8567-15591c8a949f","type":"ResetTool"},{"id":"19e31c21-4be5-489b-9300-9201a3724f72","type":"WheelZoomTool"},{"id":"52e8d0a0-5f55-4d44-8642-32eee96fde48","type":"PanTool"}]},"id":"ee0f0a8f-a53e-4b72-8462-778bd9b564fa","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":4}],"color":["#00ad9c"],"disciplina_ID":[4],"fill_alpha":[0.8],"height":[163.0],"label":[{"disciplina_ID":4}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["4"],"y":[81.5]}},"id":"44524318-5113-4ad5-87a9-8a0aeae2491d", ...

# %%
data2 = data
data2['count'] = 0
data2.head()
# Out:
#    a_ID       CEP  ano_ingresso  periodo_ingresso     status  ano_disciplina  \
# 0     0  59015430          2014                 1  CANCELADO            2014
# 1     0  59015430          2014                 1  CANCELADO            2015
# 2     1  59073120          2014                 1  CANCELADO            2014
# 3     2  59072580          2014                 1      ATIVO            2014
# 4     3  59088150          2014                 1      ATIVO            2014
#
#    periodo_disciplina  nota  disciplina_ID status.disciplina  enem-matematica  \
# 0                   2   2.6              0         Reprovado             2172
# 1                   1   8.0              0          Aprovado             2172
# 2                   2   0.1              0         Reprovado             1955
# 3                   2   6.1              0          Aprovado             1959
# 4                   1   3.0              0         Reprovado             2235
#
#    enem-nota  enem-redacao  enen-nota  count
# 0          0           640      618.0      0
# 1          0           640      618.0      0
# 2          0           660      615.0      0
# 3          0           560      600.0      0
# 4          0           760      673.0      0

# %%
dataYear2014_nota = data2[data2["ano_disciplina"] == 2014]
dataYear2015_nota = data2[data2["ano_disciplina"] == 2015]
dataYear2016_nota = data2[data2["ano_disciplina"] == 2016]

# %%
NotasYear2014 = BoxPlot(dataYear2014_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID', legend = False, 
             title = "BoxPlot das disciplinas pelas notas, Ano 2014", tools = [TOOLS])

NotasYear2015 = BoxPlot(dataYear2015_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2015", tools = [TOOLS])

NotasYear2016 = BoxPlot(dataYear2016_nota, values='nota', label='disciplina_ID', color = 'disciplina_ID',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2016", tools = [TOOLS])

# %% [markdown]
# ## Gráfico 3 - Disciplinas x Notas em cada ano.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# "Pesquisas recentes têm observado que muitos fatores podem influenciar o desempenho de um estudante: conhecimentos anteriores, infraestrutura (materiais adequados e espaço físico para estudar), emocionais (estresse e autoconfiança), desempenho do professor (didática, pontualidade, provas em nível adequado e indicação de literatura apropriada) e esforço pessoal do estudante (estar presente nas aulas, prestar atenção, tirar dúvidas, estudar em casa e saber administrar o tempo)."
#
# #### Cesar Duarte Souto-Maior, José Alonso Borba, Paulo de Souza Knupp, Eva de Souza Croll
# **Análise de Fatores que Afetam o Desempenho de Alunos de Graduação em Administração e Contabilidade na Disciplina de Pesquisa Operacional**
#
# Analisando as disciplinas, no ano de 2014, podemos ver as disciplinas 3 e 5, com medianas em 2,2 e 2,9 respectavemente, que consideram o valor da média final da maioria dos alunos. Mas enquanto a disciplina 3 se mantém com o mesmo valor no decorrer dos anos, a disciplina 5 em 2016 teve como mediana 1,8 e cerca de 50% dos alunos com nota final igual ou inferior a 4,1.
# As disciplinas 1, 2 e 4 matém os mesmos níveis de distribuições no decorrer dos anos. A disciplina 6 teve uma distribuição menos concentrada nos anos de 2015 e 2016.

# %%
row1 = [NotasYear2014,NotasYear2015]

# Create a list containing plots p3 and p4: row2
row2 = [NotasYear2016]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1ef27d7f-33db-4d9c-a645-9010e9d60b8e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="356a6878-e73c-4cae-a89c-48422aa18d24"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("356a6878-e73c-4cae-a89c-48422aa18d24").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("356a6878-e73c-4cae-a89c-48422aa18d24");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '356a6878-e73c-4cae-a89c-48422aa18d24' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"90174073-2970-461f-a7b1-24c438a5e0b2":{"roots":{"references":[{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"004d0726-36f1-471e-b54d-6f2b87e4e502","type":"Segment"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"10827016-64fd-4e98-a0d6-14f414f64fcc","type":"Segment"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"45918be6-7744-4456-9ac9-ece1650e7940","type":"Rect"},{"attributes":{"axis_label":"Nota","formatter":{"id":"d68f3341-646b-4be2-a8a2-04b82a5ad387","type":"BasicTickFormatter"},"plot":{"id":"b2eaefd4-79a1-428f-a66e-91bb9790f32d","subtype":"Chart","type":"Plot"},"ticker":{"id":"406b98af-1b7e-40b3-bce4-90fbe0b4e5e4","type":"BasicTicker"}},"id":"88195571-5eee-4f77-b35c-6bbf79f8d7dd","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8c6c7721-2d95-4beb-b474-786de00cd27d","type":"Rect"},{"attributes":{"data_source":{"id":"a7e54e88-ea05-4197-b583-be56edbd66ee","type":"ColumnDataSource"},"glyph":{"id":"393222be-97c6-4cab-b3c0-189e96e26e0c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3a3c9250-958f-4a77-9a0c-cb2b21b7b289","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1f6a9d4e-d7d0-4af6-909f-2a395a70d110","type":"ColumnDataSource"},"glyph":{"id":"31ebfd17-9033-44a2-9045-38318bd2ee68","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c952cd64-6917-444a-892f-439137668015","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":6}],"color":["#f22c40"],"disciplina_ID":[6],"fill_alpha":[0.8],"height":[1.0499999999999998],"label":[{"disciplina_ID":6}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["6"],"y":[5.175000000000001]}},"id":"46f9de89-d43d-417e-aa2c-e2e9a49643ad","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7717a11f-e177-4462-ba71-ce0b4f310eba","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"e7112ca6-5bad-4f01-a21c-9a01042d57f0","type":"Segment"},{"attributes":{"data_source":{"id":"a6a85e72-e045-401f-83a4-b2edbc32f301","type":"ColumnDataSource"},"glyph":{"id":"10827016-64fd-4e98-a0d6-14f414f64fcc","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"496691ad-9401-4721-8ad4-08f13a2aed73","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":4}],"color":["#00ad9c"],"disciplina_ID":[4],"fill_alpha":[0.8],"height":[0.7999999999999998],"label":[{"disciplina_ID":4}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["4"],"y":[5.800000000000001]}},"id":"cb093739-cd48-4674-8cc7-1f6b37a96048","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"disciplina_ID":5},{"disciplina_ID":5},{"disciplina_ID":5},{"disciplina_ID":5}],"disciplina_ID":[5,5,5,5],"x0s":["5:0.5","5:0.65","5:0.5","5:0.65"],"x1s":["5:0.5","5:0.35","5:0. ...

# %% [markdown]
# ## Gráfico 4 - Disciplinas x Notas em todos os anos.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# Analisando as disciplinas, podemos ver as disciplinas 3 e 5, com quase 50% de seus alunos com médias abaixo de 5.
# As disciplinas 1 e 4 matém os mesmos níveis de distribuições, olhando para o fato de terem vários Outliers. A disciplina 6 teve uma distribuição menos concentrada com mediana aproximadamente em 4 e as disciplinas 0 e 2 com valores próximos a 5,2.

# %%
BoxPlot_Nota = BoxPlot(data, values='nota', label='disciplina_ID', legend = 'top_right', color = 'disciplina_ID', tools = [TOOLS])

output_notebook()


show(BoxPlot_Nota)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8127ef69-85d0-4e2a-bdf4-392a53d54c2f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c0f93f0c-fbe2-4479-bd09-00b7726d2c71"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c0f93f0c-fbe2-4479-bd09-00b7726d2c71").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0f93f0c-fbe2-4479-bd09-00b7726d2c71");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0f93f0c-fbe2-4479-bd09-00b7726d2c71' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"01cbc236-2f2c-413f-815a-24e5fef72708":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":6}],"color":["#f22c40"],"disciplina_ID":[6],"fill_alpha":[0.8],"height":[2.5],"label":[{"disciplina_ID":6}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["6"],"y":[5.55]}},"id":"2a8eb05e-f347-44ef-afa4-bf8f837092c1","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c74cd31a-75d6-4c0f-a978-e155f3e43136","type":"Rect"},{"attributes":{"callback":null,"end":10.5},"id":"8350df61-1c89-4f5e-a394-b150e1332241","type":"Range1d"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"1bf28cba-6183-467f-b376-7601095c4718","type":"Segment"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"disciplina_ID":6}],"color":["#f22c40"],"disciplina_ID":[6],"fill_alpha":[0.8],"height":[3.3],"label":[{"disciplina_ID":6}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["6"],"y":[2.65]}},"id":"6deb6bcd-7b78-4d89-9c53-8abd5190161c","type":"ColumnDataSource"},{"attributes":{},"id":"4495b824-2b5c-4848-9e34-cfd7cdc1dbae","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"disciplina_ID":5},{"disciplina_ID":5},{"disciplina_ID":5},{"disciplina_ID":5}],"disciplina_ID":[5,5,5,5],"x0s":["5:0.5","5:0.65","5:0.5","5:0.65"],"x1s":["5:0.5","5:0.35","5:0.5","5:0.35"],"y0s":[0.0,0.0,5.5,10.0],"y1s":[0.8,0.0,10.0,10.0]}},"id":"5f9ac500-4a1f-43af-8322-5447a957e84b","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"7f371259-08bc-4f47-9439-d62958760d73","type":"LegendItem"},{"id":"df0b1bbb-2fa9-4e9c-bbcc-cc13fb6ad914","type":"LegendItem"},{"id":"87c9952b-b906-4dee-b288-a3a49c06155d","type":"LegendItem"},{"id":"81fa744f-711d-48bb-8922-537a652ab717","type":"LegendItem"},{"id":"a50dd43b-f7df-40ac-a36a-3c78b7fbf131","type":"LegendItem"},{"id":"b76581ce-a009-40ca-9b3e-f12752642d58","type":"LegendItem"},{"id":"8f4915a8-ee6e-4c1c-8188-4d4e4b94e63e","type":"LegendItem"}],"plot":{"id":"3793292d-ccc2-4742-96bf-236d0ea23a39","subtype":"Chart","type":"Plot"}},"id":"6e19e493-988a-4fa4-ba10-2d248ccc55b7","type":"Legend"},{"attributes":{},"id":"4379c96f-9ef7-4a3d-98dd-109e7de714bf","type":"ToolEvents"},{"attributes":{"data_source":{"id":"5f9ac500-4a1f-43af-8322-5447a957e84b","type":"ColumnDataSource"},"glyph":{"id":"1bf28cba-6183-467f-b376-7601095c4718","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9bf4f867-3caf-48f6-9a32-d04315f93e23","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d7b69d8c-db6c-4e71-a797-8d0d5420d416","type":"BoxZoomTool"},{"id":"87eb1b9b-3c0c-4113-b931-c398245a0676","type":"BoxSelectTool"},{"id":"e391f3b0-2f94-4690-8a99-7e57be0016ee","type":"CrosshairTool"},{"id":"a2c370d1-9561-4f36-aa1b-1c1a1ab28b49","type":"ResizeTool"},{"id":"ec56bbd6-0af4-4815-91c2-44538dbbf54b","type":"ResetTool"},{"id":"88506656-31d5-4936-b6c5-338a7794506a","type":"WheelZoomTool"},{"id":"5b45a52d-62da-4946-a032-62c5f1d595da","type":"PanTool"}]},"id":"c27069f8-dfe7-42c4-8fd6-815e2641666e","type":"Toolbar"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"daea0f06-7418-4f87-81bb-b251a3efb875","type":"GlyphRenderer"},{"id":"f6daa8c6-e49b-4c1b-811d-46b005ef8ad9","type":"GlyphRenderer"},{"id":"ec8f06f4-0e05-48ca-a413-f3b3d792a475","type":"GlyphRenderer"}]},"id":"7f371259-08bc-4f47-9439-d62958760d73","type":"Lege ...

# %%
Notas_Enem2014 = BoxPlot(data, values='enen-nota', label='ano_ingresso', color = 'ano_ingresso', legend = 'bottom_right', 
             title = "BoxPlot Notas do Enem pelo Ano de Ingresso", tools = [TOOLS])

Notas_Enem2015 = BoxPlot(data, values='enem-redacao', label='ano_ingresso', color = 'ano_ingresso', legend = 'bottom_right', 
             title = "BoxPlot Notas da Redação Enem pelo Ano de Ingresso", tools = [TOOLS])
Notas_Enem2016 = BoxPlot(data, values='enem-matematica', label='ano_ingresso', color = 'ano_ingresso', legend = False, 
             title = "BoxPlot Notas de Matemática Enem pelo Ano de Ingresso", tools = [TOOLS])

# %% [markdown]
# ## Gráfico 5 - Notas Enem x Ano de Ingresso.
#
# Nesta seção utilizamos os dados das notas do Enem dos alunos em relação ao ano de ingresso.
#
# No primeiro Gráfico, podemos ver que apesar de alguns poucos Outliers para cima ou para baixo da distruibuição, a média geral dos alunos se manteve próxima aos 620 pontos em todos oos anos.
#
# No segundo Gráfico para as notas da redação, com uma distruibuição um pouco menos concentrada do que as notas gerais, ainda assim temos cerca 50% dos alunos com notas em torno de 600 à bem próximo dos 800, que no geral chegam a ser boas notas.
#
# No terceiro Gráfico............

# %%
row1 = [Notas_Enem2014,Notas_Enem2015]

# Create a list containing plots p3 and p4: row2
row2 = [Notas_Enem2016]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1,row2],plot_width=450, plot_height=450)

output_notebook()


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9560dfc0-da7d-45ab-aa1d-69f7e39cb970">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ddd3561d-5629-4025-b4b2-27cd78a54c4e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ddd3561d-5629-4025-b4b2-27cd78a54c4e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ddd3561d-5629-4025-b4b2-27cd78a54c4e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ddd3561d-5629-4025-b4b2-27cd78a54c4e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a05b7187-d6d9-4c28-ad37-0a3b0c47c0dd":{"roots":{"references":[{"attributes":{"data_source":{"id":"0f8b81a6-b4fd-4334-8499-c0aec8544ce2","type":"ColumnDataSource"},"glyph":{"id":"07465d3e-9195-44a1-af9a-e138bfe5ceb5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"39756cf6-1b02-4826-94c2-8b164c4a9061","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"ano_ingresso":[2016],"chart_index":[{"ano_ingresso":2016}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[80.0],"label":[{"ano_ingresso":2016}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["2016"],"y":[700.0]}},"id":"0f8b81a6-b4fd-4334-8499-c0aec8544ce2","type":"ColumnDataSource"},{"attributes":{},"id":"ec67a1e3-4342-4303-8f17-e00429992a07","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"ano_ingresso":[2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016],"chart_index":[{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016},{"ano_ingresso":2016}],"x_values":["2016:0.5","2016:0.5","2016:0.5","2016:0.5","2016:0.5","2016:0. ...

# %% [markdown]
# ### Usando plotly para gerar gráficos pizza de acordo com os dados fornecidos.

# %%
# Filter by status (ATIVO, CANCELADO and TRANCADO)
a = data
a = a.loc[a['status'] != 'FORMADO']
a = a.loc[a['status'] != 'FORMANDO']
a = a.loc[a['status'] != 'CONCLUIDO']
a = a.loc[a['status'] != 'FORMADO']
a = pd.DataFrame(a.groupby('status')['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2014
a14 = data.loc[data['ano_ingresso'] == 2014]
a14 = a14.loc[a14['status'] != 'FORMADO']
a14 = a14.loc[a14['status'] != 'FORMANDO']
a14 = a14.loc[a14['status'] != 'CONCLUIDO']
a14 = a14.loc[a14['status'] != 'FORMADO']
a14 = pd.DataFrame(a14.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2015
a15 = data.loc[data['ano_ingresso'] == 2015]
a15 = a15.loc[a15['status'] != 'FORMADO']
a15 = a15.loc[a15['status'] != 'FORMANDO']
a15 = a15.loc[a15['status'] != 'CONCLUIDO']
a15 = a15.loc[a15['status'] != 'FORMADO']
a15 = pd.DataFrame(a15.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# Filter by status (ATIVO, CANCELADO and TRANCADO) and year of 2016
a16 = data.loc[data['ano_ingresso'] == 2016]
a16 = a16.loc[a16['status'] != 'FORMADO']
a16 = a16.loc[a16['status'] != 'FORMANDO']
a16 = a16.loc[a16['status'] != 'CONCLUIDO']
a16 = a16.loc[a16['status'] != 'FORMADO']
a16 = pd.DataFrame(a16.groupby(['ano_ingresso', 'status'])['a_ID'].count()).reset_index()

# %%
# Load data from dataframes into figure object
fig = {
    'data': [
        {
            'labels': a16['status'],
            'values': a16['a_ID'],
            'type': 'pie',
            'name': '2016',
            'domain': {'x': [0, .48], 'y': [0, .49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a['status'],
            'values': a['a_ID'],
            'type': 'pie',
            'name': '2014-2016',
            'domain': {'x': [.52, 1], 'y': [0, .49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a14['status'],
            'values': a14['a_ID'],
            'type': 'pie',
            'name': '2014',
            'domain': {'x': [0, .48], 'y': [.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': a15['status'],
            'values': a15['a_ID'],
            'type': 'pie',
            'name':'2015',
            'domain': {'x': [.52, 1], 'y': [.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Distribuição de alunos por ano de ingresso e situação',
        'annotations':[
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2014',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2015',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 18},
                    'showarrow': False,
                    'text': '2016',
                    'x': 0.21,
                    'y': 0.21
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': '14 - 16',
                    'x': 0.79,
                    'y': 0.21
                }
        ]
    }
}

# %% [markdown]
# ## Gráfico 6 - Ano de Ingresso x Status.
#
# Para verificar o andamento anual do curso, decidimos analisar a situação dos alunos (status) a cada ano e também ao total dos 3 anos.
#
# Nesta seção utilizamos os dados dos status dos alunos em relação ao seus anos de ingresso.

# %%
# Plot pie charts
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~edumarques/120.embed" height="525px" width="100%"></iframe>

# %%
d = data
d['count'] = 0

# Filter by qtd_matriculas and disciplina 0
d0 = d[d['disciplina_ID']==0]
d0 = pd.DataFrame(d0.groupby('a_ID')['count'].count()).reset_index()
d0 = d0.rename(columns = {'count':'qtd_matriculas'})
d0['count'] = 0
d0 = pd.DataFrame(d0.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 1
d1 = d[d['disciplina_ID']==1]
d1 = pd.DataFrame(d1.groupby('a_ID')['count'].count()).reset_index()
d1 = d1.rename(columns = {'count':'qtd_matriculas'})
d1['count'] = 0
d1 = pd.DataFrame(d1.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 2
d2 = d[d['disciplina_ID']==2]
d2 = pd.DataFrame(d2.groupby('a_ID')['count'].count()).reset_index()
d2 = d2.rename(columns = {'count':'qtd_matriculas'})
d2['count'] = 0
d2 = pd.DataFrame(d2.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 3
d3 = d[d['disciplina_ID']==3]
d3 = pd.DataFrame(d3.groupby('a_ID')['count'].count()).reset_index()
d3 = d3.rename(columns = {'count':'qtd_matriculas'})
d3['count'] = 0
d3 = pd.DataFrame(d3.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 4
d4 = d[d['disciplina_ID']==4]
d4 = pd.DataFrame(d4.groupby('a_ID')['count'].count()).reset_index()
d4 = d4.rename(columns = {'count':'qtd_matriculas'})
d4['count'] = 0
d4 = pd.DataFrame(d4.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 5
d5 = d[d['disciplina_ID']==5]
d5 = pd.DataFrame(d5.groupby('a_ID')['count'].count()).reset_index()
d5 = d5.rename(columns = {'count':'qtd_matriculas'})
d5['count'] = 0
d5 = pd.DataFrame(d5.groupby('qtd_matriculas')['count'].count()).reset_index()

# Filter by qtd_matriculas and disciplina 6
d6 = d[d['disciplina_ID']==6]
d6 = pd.DataFrame(d6.groupby('a_ID')['count'].count()).reset_index()
d6 = d6.rename(columns = {'count':'qtd_matriculas'})
d6['count'] = 0
d6 = pd.DataFrame(d6.groupby('qtd_matriculas')['count'].count()).reset_index()

# %%
# Load data from dataframes into figure object
fig1 = {
    'data': [
        {
            'labels': d2['qtd_matriculas'],
            'values': d2['count'],
            'type': 'pie',
            'name': 'Disciplina 2',
            'domain': {'x': [0, .48], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d3['qtd_matriculas'],
            'values': d3['count'],
            'type': 'pie',
            'name': 'Disciplina 3',
            'domain': {'x': [.52, 1], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d0['qtd_matriculas'],
            'values': d0['count'],
            'type': 'pie',
            'name': 'Disciplina 0',
            'domain': {'x': [0, .48], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d1['qtd_matriculas'],
            'values': d1['count'],
            'type': 'pie',
            'name':'Disciplina 1',
            'domain': {'x': [.52, 1], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Disciplina pela Quantidade de vezes que alunos se matricularam (Disciplina 0 à 3)',
        'annotations':[
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_0',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_1',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_2',
                    'x': 0.21,
                    'y': 0.21
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_3',
                    'x': 0.79,
                    'y': 0.21
                }
        ]
    }
}

# %% [markdown]
# ## Gráfico 6 - Disciplina x Quantida de vezes que alunos se matricularam
#
# De acordo com o regulamento da UFRN, é previsto o cancelamento do programa se houver desempenho acadêmico insuficiente por parte do aluno. Ainda de acordo com o regulamento, **Seção III (15.16.3. DO DESEMPENHO ACADÊMICO INSUFICIENTE), Art. 327 - I**:
#
# ***"Caracteriza-se o desempenho acadêmico insuficiente quando, em um período letivo regular no qual o programa não está suspenso, ocorre uma ou mais das seguintes situações: Insucesso (trancamento e/ou reprovação) pela quarta vez ou mais, consecutiva ou não, em um mesmo componente curricular obrigatório ou seus equivalentes;"***
#
#
# Com o objetivo de verificar o andamento de cada disciplina e assim analisar quais têm causado mais dificuldades aos alunos, inclusive abrindo possibilidades de cancelamento de seus programas, levantamos os dados que mostram a quantidade de vezes que os alunos se matricularam nas disciplinas no decorrer do tempo (intervalo de 2014 à 2016).

# %%
# Plot pie charts
py.iplot(fig1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~edumarques/126.embed" height="525px" width="100%"></iframe>

# %%
fig2 = {
    'data': [
        {
            'labels': d6['qtd_matriculas'],
            'values': d6['count'],
            'type': 'pie',
            'name': 'Disciplina 6',
            'domain': {'x': [0, .48], 'y': [0, 0.49]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d4['qtd_matriculas'],
            'values': d4['count'],
            'type': 'pie',
            'name': 'Disciplina 4',
            'domain': {'x': [0, .48], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        {
            'labels': d5['qtd_matriculas'],
            'values': d5['count'],
            'type': 'pie',
            'name':'Disciplina 5',
            'domain': {'x': [.52, 1], 'y': [0.51, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        }
    ],
    'layout':{
        'title': 'Disciplina pela Quantidade de vezes que alunos se matricularam (Disciplina 4 à 6)',
        'annotations':[
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_4',
                    'x': 0.21,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_5',
                    'x': 0.79,
                    'y': 0.8
                },
                {
                    'font': {'size': 15},
                    'showarrow': False,
                    'text': 'Disc_6',
                    'x': 0.21,
                    'y': 0.21
                }
        ]
    }
}

# %%
py.iplot(fig2)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~edumarques/128.embed" height="525px" width="100%"></iframe>
